# %% [markdown]
# ## Before you start :
#    - These exercises are related to the Exploratory data analysis using matplotlib and seaborn.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - The datasets for Challenge 2 and 3 are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
#import libraries here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# /home/ivan/snap/jupyter/common/lib/python3.7/site-packages/joblib/_multiprocessing_helpers.py:53: UserWarning: [Errno 13] Permission denied.  joblib will operate in serial mode
#   warnings.warn('%s.  joblib will operate in serial mode' % (e,))

# %% [markdown]
# #### Define data.

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x,y) and (x,z) on the axes.
#
# #### There are 2 ways of doing this. Do in both ways.
#
# *Hint: Check out the `nrows`, `ncols`, and `index` arguments of [subplots](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html)*
#
# #### Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# your code here-1st way (call `subplots` twice using the `index` parameter)
plt.subplot(1,2,1)
plt.plot(x)
plt.plot(y)
plt.subplot(1,2,2,)
plt.plot(x,linewidth=5)
plt.plot(z,linestyle='dashed')

# %%
# your code here-2st way (call `subplots` only once not using the `index` parameter)
for i in range(2):
    plt.subplot(1,2,i+1)
    plt.plot(x)
    plt.plot(y)

# %% [markdown]
# #### Augmenting your previous code, resize your previous plot.
#
# *Hint: Add the `figsize` argument in `plt.subplots()`*

# %%
# your code here
plt.figure(figsize=(13,5))
plt.subplot(1,2,1)
plt.plot(x)
plt.plot(y)
plt.subplot(1,2,2,)
plt.plot(x,linewidth=5)    
plt.plot(z,linestyle='dashed')

# %% [markdown]
# #### Augmenting your previous code, label your axes.
#
# *Hint: call `set_xlabel` and `set_ylabel`*

# %%
# your code here
plt.figure(figsize=(10,5))
plt.plot(x,y)
plt.xlabel("X")
plt.ylabel("X**2")
# Out:
# Text(0, 0.5, 'X**2')

# %% [markdown]
# #### Plot both `y=x^2` and `y=exp(x)` in the same plot using normal and logarithmic scale.
#
# *Hint: Use `set_xscale` and `set_yscale`*

# %%
# your code here
plt.figure(figsize=(13,5))
plt.subplot(1,2,1)
plt.plot(x, y)
plt.yscale('linear')
plt.subplot(1,2,2)
plt.plot(x, y)
plt.xscale('log')

# %% [markdown]
# #### In the vehicles data set that you have downloaded, use the vehicles.csv file. In this exercise we will conduct some exploratory data analysis using one plot each of scatter plot, box plot, histogram, and bar chart.

# %% [markdown]
# Scatter Plot
#
# Please provide a scatter plot between "Combined MPG" as X variable and
# "Highway MPG" as Y variable

# %%
# your code here
df=pd.read_csv("vehicles.csv")
df.head()
plt.scatter(df['Combined MPG'], df['Highway MPG'])
plt.xlabel("Combined MPG")
plt.ylabel("Highway MPG")
# Out:
# Text(0, 0.5, 'Highway MPG')

# %% [markdown]
# Box Whisker Plot
#
# Please provide a box plot of the variable "CO2 Emission Grams/mile"

# %%
# your code here
plt.figure(figsize=(8,12))
plt.boxplot(df['CO2 Emission Grams/Mile'])
plt.title("Boxplot CO2 Emission Grams")
# Out:
# Text(0.5, 1.0, 'Boxplot CO2 Emission Grams')

# %% [markdown]
# Histogram
#
# Please provide a histogram of the Fuel Barrels/Year

# %%
# your code here
plt.hist(df['Fuel Cost/Year'],30)
# Out:
# (array([6.800e+01, 2.360e+02, 1.069e+03, 1.466e+03, 4.807e+03, 4.224e+03,
#         4.637e+03, 5.749e+03, 4.328e+03, 3.172e+03, 2.118e+03, 1.517e+03,
#         9.540e+02, 4.010e+02, 6.320e+02, 8.100e+01, 2.320e+02, 1.760e+02,
#         0.000e+00, 5.300e+01, 1.700e+01, 0.000e+00, 6.000e+00, 0.000e+00,
#         0.000e+00, 4.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 5.000e+00]),
#  array([ 600.        ,  773.33333333,  946.66666667, 1120.        ,
#         1293.33333333, 1466.66666667, 1640.        , 1813.33333333,
#         1986.66666667, 2160.        , 2333.33333333, 2506.66666667,
#         2680.        , 2853.33333333, 3026.66666667, 3200.        ,
#         3373.33333333, 3546.66666667, 3720.        , 3893.33333333,
#         4066.66666667, 4240.        , 4413.33333333, 4586.66666667,
#         4760.        , 4933.33333333, 5106.66666667, 5280.        ,
#         5453.33333333, 5626.66666667, 5800.        ]),
#  <a list of 30 Patch objects>)

# %% [markdown]
# Bar Chart
#
# Please provide a bar chart of the Fuel Type on the X axis and "City MPG" on the Y axis

# %%
# your code here
plt.figure(figsize=(15,11))
plt.bar(df['Fuel Type'], df['City MPG'], align='center', alpha=0.5)
plt.xticks(df['Fuel Type'], df['City MPG'])
# Out:
# ([<matplotlib.axis.XTick at 0x7f4027cd6c18>,
#   <matplotlib.axis.XTick at 0x7f4027cd6160>,
#   <matplotlib.axis.XTick at 0x7f4027cd62b0>,
#   <matplotlib.axis.XTick at 0x7f400cdb1ac8>,
#   <matplotlib.axis.XTick at 0x7f400cdb1f28>,
#   <matplotlib.axis.XTick at 0x7f400cdbb4e0>,
#   <matplotlib.axis.XTick at 0x7f400cdbba58>,
#   <matplotlib.axis.XTick at 0x7f400cdbbba8>,
#   <matplotlib.axis.XTick at 0x7f400cdc2588>,
#   <matplotlib.axis.XTick at 0x7f400cdc2b00>,
#   <matplotlib.axis.XTick at 0x7f400cdc9128>,
#   <matplotlib.axis.XTick at 0x7f400cdc2e80>,
#   <matplotlib.axis.XTick at 0x7f400cdbb588>,
#   <matplotlib.axis.XTick at 0x7f400cdc96a0>,
#   <matplotlib.axis.XTick at 0x7f400cdc9c18>,
#   <matplotlib.axis.XTick at 0x7f400cdd21d0>,
#   <matplotlib.axis.XTick at 0x7f400cdd2748>,
#   <matplotlib.axis.XTick at 0x7f400cdd2cc0>,
#   <matplotlib.axis.XTick at 0x7f400cdd8278>,
#   <matplotlib.axis.XTick at 0x7f400cdd87f0>,
#   <matplotlib.axis.XTick at 0x7f400cdd8d68>,
#   <matplotlib.axis.XTick at 0x7f400cdd2c18>,
#   <matplotlib.axis.XTick at 0x7f400cdc9780>,
#   <matplotlib.axis.XTick at 0x7f400cddf320>,
#   <matplotlib.axis.XTick at 0x7f400cddf898>,
#   <matplotlib.axis.XTick at 0x7f400cddfe10>,
#   <matplotlib.axis.XTick at 0x7f400cde63c8>,
#   <matplotlib.axis.XTick at 0x7f400cde6940>,
#   <matplotlib.axis.XTick at 0x7f400cde6eb8>,
#   <matplotlib.axis.XTick at 0x7f400cd6d470>,
#   <matplotlib.axis.XTick at 0x7f400cde6a20>,
#   <matplotlib.axis.XTick at 0x7f400cddf198>,
#   <matplotlib.axis.XTick at 0x7f400cd6d908>,
#   <matplotlib.axis.XTick at 0x7f400cd6de80>,
#   <matplotlib.axis.XTick at 0x7f400cd76438>,
#   <matplotlib.axis.XTick at 0x7f400cd769b0>,
#   <matplotlib.axis.XTick at 0x7f400cd76f28>,
#   <matplotlib.axis.XTick at 0x7f400cd7c4e0>,
#   <matplotlib.axis.XTick at 0x7f400cd7ca58>,
#   <matplotlib.axis.XTick at 0x7f400cd7cba8>,
#   <matplotlib.axis.XTick at 0x7f400cd76908>,
#   <matplotlib.axis.XTick at 0x7f400cddf128>,
#   <matplotlib.axis.XTick at 0x7f400cd84518>,
#   <matplotlib.axis.XTick at 0x7f400cd84a90>,
#   <matplotlib.axis.XTick at 0x7f400cd8c0b8>,
#   <matplotlib.axis.XTick at 0x7f400cd8c5c0>,
#   <matplotlib.axis.XTick at 0x7f400cd8cb38>,
#   <matplotlib.axis.XTick at 0x7f400cd93160>,
#   <matplotlib.axis.XTick at 0x7f400cd93668>,
#   <matplotlib.axis.XTick at 0x7f400cd8c9b0>,
#   <matplotlib.axis.XTick at 0x7f400cddf278>,
#   <matplotlib.axis.XTick at 0x7f400cd93b00>,
#   <matplotlib.axis.XTick at 0x7f400cd99128>,
#   <matplotlib.axis.XTick at 0x7f400cd99630>,
#   <matplotlib.axis.XTick at 0x7f400cd99ba8>,
#   <matplotlib.axis.XTick at 0x7f400cda2198>,
#   <matplotlib.axis.XTick at 0x7f400cda26d8>,
#   <matplotlib.axis.XTick at 0x7f400cda2c50>,
#   <matplotlib.axis.XTick at 0x7f400cda26a0>,
#   <matplotlib.axis.XTick at 0x7f400cd996d8>,
#   <matplotlib.axis.XTick at 0x7f400cd8c588>,
#   <matplotlib.axis.XTick at 0x7f400cda8710>,
#   <matplotlib.axis.XTick at 0x7f400cda8c88>,
#   <matplotlib.axis.XTick at 0x7f400cd2f240>,
#   <matplotlib.axis.XTick at 0x7f400cd2f7b8>,
#   <matplotlib.axis.XTick at 0x7f400cd2fd30>,
#   <matplotlib.axis.XTick at 0x7f400cd362e8>,
#   <matplotlib.axis.XTick at 0x7f400cd36860>,
#   <matplotlib.axis.XTick at 0x7f400cd2f898>,
#   <matplotlib.axis.XTick at 0x7f400cd7c358>,
#   <matplotlib.axis.XTick at 0x7f400cd36cf8>,
#   <matplotlib.axis.XTick at 0x7f400cd3f2b0>,
#   <matplotlib.axis.XTick at 0x7f400cd3f828>,
#   <matplotlib.axis.XTick at 0x7f400cd3fda0>,
#   <matplotlib.axis.XTick at 0x7f400cd45358>,
#   <matplotlib.axis.XTick at 0x7f400cd458d0>,
#   <matplotlib.axis.XTick at 0x7f400cd45e48>,
#   <matplotlib.axis.XTick at 0x7f400cd45400>,
#   <matplotlib.axis.XTick at 0x7f400cd3f7f0>,
#   <matplotlib.axis.XTick at 0x7f400cd4d400>,
#   <matplotlib.axis.XTick at 0x7f400cd4d908>,
#   <matplotlib.axis.XTick at 0x7f400cd4de80>,
#   <matplotlib.axis.XTick at 0x7f400cd54438>,
#   <matplotlib.axis.XTick at 0x7f400cd549b0>,
#   <matplotlib.axis.XTick at 0x7f400cd54f28>,
#   <matplotlib.axis.XTick at 0x7f400cd5b4e0>,
#   <matplotlib.axis.XTick at 0x7f400cd5ba58>,
#   <matplotlib.axis.XTick at 0x7f400cd54908>,
#   <matplotlib.axis.XTick at 0x7f400cd3f358>,
#   <matplotlib.axis.XTick at 0x7f400cd5bef0>,
#   <matplotlib.axis.XTick at 0x7f400cd634a8>,
#   <matplotlib.axis.XTick at 0x7f400cd63a20>,
#   <matplotlib.axis.XTick at 0x7f400cd63e80>,
#   <matplotlib.axis.XTick at 0x7f400cd69550>,
#   <matplotlib.axis.XTick at 0x7f400cd69ac8>,
#   <matplotlib.axis.XTick at 0x7f400ccf10f0>,
#   <matplotlib.axis.XTick at 0x7f400cd69518>,
#   <matplotlib.axis.XTick at 0x7f400cd63550>,
#   <matplotlib.axis.XTick at 0x7f400ccf14a8>,
#   <matplotlib.axis.XTick at 0x7f400ccf1b00>,
#   <matplotlib.axis.XTick at 0x7f400ccf8128>,
#   <matplotlib.axis.XTick at 0x7f400ccf8630>,
#   <matplotlib.axis.XTick at 0x7f400ccf8ba8>,
#   <matplotlib.axis.XTick at 0x7f400cd00198>,
#   <matplotlib.axis.XTick at 0x7f400cd006d8>,
#   <matplotlib.axis.XTick at 0x7f400cd00c50>,
#   <matplotlib.axis.XTick at 0x7f400cd007b8>,
#   <matplotlib.axis.XTick at 0x7f400ccf8f98>,
#   <matplotlib.axis.XTick at 0x7f400cd09198>,
#   <matplotlib.axis.XTick at 0x7f400cd096a0>,
#   <matplotlib.axis.XTick at 0x7f400cd09c18>,
#   <matplotlib.axis.XTick at 0x7f400cd101d0>,
#   <matplotlib.axis.XTick at 0x7f400cd10748>,
#   <matplotlib.axis.XTick at 0x7f400cd10cc0>,
#   <matplotlib.axis.XTick at 0x7f400cd16278>,
#   <matplotlib.axis.XTick at 0x7f400cd10278>,
#   <matplotlib.axis.XTick at 0x7f400cd10048>,
#   <matplotlib.axis.XTick at 0x7f400ccf1400>,
#   <matplotlib.axis.XTick at 0x7f400cd7ce48>,
#   <matplotlib.axis.XTick at 0x7f400cd16a20>,
#   <matplotlib.axis.XTick at 0x7f400cd16e48>,
#   <matplotlib.axis.XTick at 0x7f400cd1d400>,
#   <matplotlib.axis.XTick at 0x7f400cd1d978>,
#   <matplotlib.axis.XTick at 0x7f400cd1def0>,
#   <matplotlib.axis.XTick at 0x7f400cd254a8>,
#   <matplotlib.axis.XTick at 0x7f400cd1dfd0>,
#   <matplotlib.axis.XTick at 0x7f400cd7cf28>,
#   <matplotlib.axis.XTick at 0x7f400cd25588>,
#   <matplotlib.axis.XTick at 0x7f400cd25eb8>,
#   <matplotlib.axis.XTick at 0x7f400ccab470>,
#   <matplotlib.axis.XTick at 0x7f400ccab9e8>,
#   <matplotlib.axis.XTick at 0x7f400ccabf60>,
#   <matplotlib.axis.XTick at 0x7f400ccb3518>,
#   <matplotlib.axis.XTick at 0x7f400ccb3a90>,
#   <matplotlib.axis.XTick at 0x7f400ccb3908>,
#   <matplotlib.axis.XTick at 0x7f400ccab940>,
#   <matplotlib.axis.XTick at 0x7f400cd166a0>,
#   <matplotlib.axis.XTick at 0x7f400ccba5c0>,
#   <matplotlib.axis.XTick at 0x7f400ccbab38>,
#   <matplotlib.axis.XTick at 0x7f400ccc1160>,
#   <matplotlib.axis.XTick at 0x7f400ccc1668>,
#   <matplotlib.axis.XTick at 0x7f400ccc1be0>,
#   <matplotlib.axis.XTick at 0x7f400ccc9198>,
#   <matplotlib.axis.XTick at 0x7f400ccc9710>,
#   <matplotlib.axis.XTick at 0x7f400ccc1a58>,
#   <matplotlib.axis.XTick at 0x7f400cdd8e48>,
#   <matplotlib.axis.XTick at 0x7f400ccc9ba8>,
#   <matplotlib.axis.XTick at 0x7f400ccd1198>,
#   <matplotlib.axis.XTick at 0x7f400ccd16d8>,
#   <matplotlib.axis.XTick at 0x7f400ccd1c50>,
#   <matplotlib.axis.XTick at 0x7f400ccd8208>,
#   <matplotlib.axis.XTick at 0x7f400ccd8780>,
#   <matplotlib.axis.XTick at 0x7f400ccd8cf8>,
#   <matplotlib.axis.XTick at 0x7f400ccd8588>,
#   <matplotlib.axis.XTick at 0x7f400ccd17b8>,
#   <matplotlib.axis.XTick at 0x7f400cd939e8>,
#   <matplotlib.axis.XTick at 0x7f400ccde7b8>,
#   <matplotlib.axis.XTick at 0x7f400ccded30>,
#   <matplotlib.axis.XTick at 0x7f400cce62e8>,
#   <matplotlib.axis.XTick at 0x7f400cce6860>,
#   <matplotlib.axis.XTick at 0x7f400cce6dd8>,
#   <matplotlib.axis.XTick at 0x7f400cc6d390>,
#   <matplotlib.axis.XTick at 0x7f400cc6d908>,
#   <matplotlib.axis.XTick at 0x7f400cce6940>,
#   <matplotlib.axis.XTick at 0x7f400ccab518>,
#   <matplotlib.axis.XTick at 0x7f400cc6dda0>,
#   <matplotlib.axis.XTick at 0x7f400cc74358>,
#   <matplotlib.axis.XTick at 0x7f400cc748d0>,
#   <matplotlib.axis.XTick at 0x7f400cc74e48>,
#   <matplotlib.axis.XTick at 0x7f400cc7a400>,
#   <matplotlib.axis.XTick at 0x7f400cc7a978>,
#   <matplotlib.axis.XTick at 0x7f400cc7aef0>,
#   <matplotlib.axis.XTick at 0x7f400cc7a4a8>,
#   <matplotlib.axis.XTick at 0x7f400cc74898>,
#   <matplotlib.axis.XTick at 0x7f400cc814a8>,
#   <matplotlib.axis.XTick at 0x7f400cc819b0>,
#   <matplotlib.axis.XTick at 0x7f400cc81f28>,
#   <matplotlib.axis.XTick at 0x7f400cc894e0>,
#   <matplotlib.axis.XTick at 0x7f400cc89a58>,
#   <matplotlib.axis.XTick at 0x7f400cc89ba8>,
#   <matplotlib.axis.XTick at 0x7f400cc91588>,
#   <matplotlib.axis.XTick at 0x7f400cc91b00>,
#   <matplotlib.axis.XTick at 0x7f400cc89a20>,
#   <matplotlib.axis.XTick at 0x7f400cc74438>,
#   <matplotlib.axis.XTick at 0x7f400cc91400>,
#   <matplotlib.axis.XTick at 0x7f400cc9c550>,
#   <matplotlib.axis.XTick at 0x7f400cc9cac8>,
#   <matplotlib.axis.XTick at 0x7f400cca10f0>,
#   <matplotlib.axis.XTick at 0x7f400cca15f8>,
#   <matplotlib.axis.XTick at 0x7f400cca1b70>,
#   <matplotlib.axis.XTick at 0x7f400cca8160>,
#   <matplotlib.axis.XTick at 0x7f400cca1400>,
#   <matplotlib.axis.XTick at 0x7f400cc9c630>,
#   <matplotlib.axis.XTick at 0x7f400cca8550>,
#   <matplotlib.axis.XTick at 0x7f400cca8ba8>,
#   <matplotlib.axis.XTick at 0x7f400cc30198>,
#   <matplotlib.axis.XTick at 0x7f400cc306d8>,
#   <matplotlib.axis.XTick at 0x7f400cc30c50>,
#   <matplotlib.axis.XTick at 0x7f400cc36208>,
#   <matplotlib.axis.XTick at 0x7f400cc36780>,
#   <matplotlib.axis.XTick at 0x7f400cc36cf8>,
#   <matplotlib.axis.XTick at 0x7f400cc36860>,
#   <matplotlib.axis.XTick at 0x7f400cc30a58>,
#   <matplotlib.axis.XTick at 0x7f400cc3d208>,
#   <matplotlib.axis.XTick at 0x7f400cc3d748>,
#   <matplotlib.axis.XTick at 0x7f400cc3dcc0>,
#   <matplotlib.axis.XTick at 0x7f400cc44278>,
#   <matplotlib.axis.XTick at 0x7f400cc447f0>,
#   <matplotlib.axis.XTick at 0x7f400cc44d68>,
#   <matplotlib.axis.XTick at 0x7f400cc4c320>,
#   <matplotlib.axis.XTick at 0x7f400cc44320>,
#   <matplotlib.axis.XTick at 0x7f400cc3d550>,
#   <matplotlib.axis.XTick at 0x7f400cc4c668>,
#   <matplotlib.axis.XTick at 0x7f400cc4cda0>,
#   <matplotlib.axis.XTick at 0x7f400cc54358>,
#   <matplotlib.axis.XTick at 0x7f400cc548d0>,
#   <matplotlib.axis.XTick at 0x7f400cc54e48>,
#   <matplotlib.axis.XTick at 0x7f400cc5a400>,
#   <matplotlib.axis.XTick at 0x7f400cc5a978>,
#   <matplotlib.axis.XTick at 0x7f400cc5aef0>,
#   <matplotlib.axis.XTick at 0x7f400cc5aa58>,
#   <matplotlib.axis.XTick at 0x7f400cc54978>,
#   <matplotlib.axis.XTick at 0x7f400cc613c8>,
#   <matplotlib.axis.XTick at 0x7f400cc61940>,
#   <matplotlib.axis.XTick at 0x7f400cc61eb8>,
#   <matplotlib.axis.XTick at 0x7f400cbea470>,
#   <matplotlib.axis.XTick at 0x7f400cbea9e8>,
#   <matplotlib.axis.XTick at 0x7f400cbeaf60>,
#   <matplotlib.axis.XTick at 0x7f400cbf1518>,
#   <matplotlib.axis.XTick at 0x7f400cbea3c8>,
#   <matplotlib.axis.XTick at 0x7f400cc61d30>,
#   <matplotlib.axis.XTick at 0x7f400cc3d0b8>,
#   <matplotlib.axis.XTick at 0x7f400ccc9b00>,
#   <matplotlib.axis.XTick at 0x7f400cbf15f8>,
#   <matplotlib.axis.XTick at 0x7f400cbf8160>,
#   <matplotlib.axis.XTick at 0x7f400cbf86a0>,
#   <matplotlib.axis.XTick at 0x7f400cbf8c18>,
#   <matplotlib.axis.XTick at 0x7f400cbff1d0>,
#   <matplotlib.axis.XTick at 0x7f400cbff748>,
#   <matplotlib.axis.XTick at 0x7f400cbf8cc0>,
#   <matplotlib.axis.XTick at 0x7f400cca85f8>,
#   <matplotlib.axis.XTick at 0x7f400cbff278>,
#   <matplotlib.axis.XTick at 0x7f400cc06198>,
#   <matplotlib.axis.XTick at 0x7f400cc06710>,
#   <matplotlib.axis.XTick at 0x7f400cc06c88>,
#   <matplotlib.axis.XTick at 0x7f400cc0e240>,
#   <matplotlib.axis.XTick at 0x7f400cc0e7b8>,
#   <matplotlib.axis.XTick at 0x7f400cc0ed30>,
#   <matplotlib.axis.XTick at 0x7f400cc0e780>,
#   <matplotlib.axis.XTick at 0x7f400cc067b8>,
#   <matplotlib.axis.XTick at 0x7f400cbfff60>,
#   <matplotlib.axis.XTick at 0x7f400cc15860>,
#   <matplotlib.axis.XTick at 0x7f400cc15dd8>,
#   <matplotlib.axis.XTick at 0x7f400cc1c390>,
#   <matplotlib.axis.XTick at 0x7f400cc1c908>,
#   <matplotlib.axis.XTick at 0x7f400cc1ce80>,
#   <matplotlib.axis.XTick at 0x7f400cc24438>,
#   <matplotlib.axis.XTick at 0x7f400cc249b0>,
#   <matplotlib.axis.XTick at 0x7f400cc1c9e8>,
#   <matplotlib.axis.XTick at 0x7f400cc4cd68>,
#   <matplotlib.axis.XTick at 0x7f400cc24e48>,
#   <matplotlib.axis.XTick at 0x7f400cbab400>,
#   <matplotlib.axis.XTick at 0x7f400cbab978>,
#   <matplotlib.axis.XTick at 0x7f400cbabef0>,
#   <matplotlib.axis.XTick at 0x7f400cbb34a8>,
#   <matplotlib.axis.XTick at 0x7f400cbb3a20>,
#   <matplotlib.axis.XTick at 0x7f400cbb3e80>,
#   <matplotlib.axis.XTick at 0x7f400cbb3400>,
#   <matplotlib.axis.XTick at 0x7f400cbab7f0>,
#   <matplotlib.axis.XTick at 0x7f400cbba438>,
#   <matplotlib.axis.XTick at 0x7f400cbbaa58>,
#   <matplotlib.axis.XTick at 0x7f400cbbaba8>,
#   <matplotlib.axis.XTick at 0x7f400cbc1588>,
#   <matplotlib.axis.XTick at 0x7f400cbc1b00>,
#   <matplotlib.axis.XTick at 0x7f400cbc8128>,
#   <matplotlib.axis.XTick at 0x7f400cbc8630>,
#   <matplotlib.axis.XTick at 0x7f400cbc8ba8>,
#   <matplotlib.axis.XTick at 0x7f400cbc1908>,
#   <matplotlib.axis.XTick at 0x7f400cbab8d0>,
#   <matplotlib.axis.XTick at 0x7f400cbd10f0>,
#   <matplotlib.axis.XTick at 0x7f400cbd15f8>,
#   <matplotlib.axis.XTick at 0x7f400cbd1b70>,
#   <matplotlib.axis.XTick at 0x7f400cbd8160>,
#   <matplotlib.axis.XTick at 0x7f400cbd86a0>,
#   <matplotlib.axis.XTick at 0x7f400cbd8c18>,
#   <matplotlib.axis.XTick at 0x7f400cbde1d0>,
#   <matplotlib.axis.XTick at 0x7f400cbd8518>,
#   <matplotlib.axis.XTick at 0x7f400cbd1550>,
#   <matplotlib.axis.XTick at 0x7f400cbde518>,
#   <matplotlib.axis.XTick at 0x7f400cbdec50>,
#   <matplotlib.axis.XTick at 0x7f400cbe6208>,
#   <matplotlib.axis.XTick at 0x7f400cbe6780>,
#   <matplotlib.axis.XTick at 0x7f400cbe6cf8>,
#   <matplotlib.axis.XTick at 0x7f400cb6d2b0>,
#   <matplotlib.axis.XTick at 0x7f400cb6d828>,
#   <matplotlib.axis.XTick at 0x7f400cb6dda0>,
#   <matplotlib.axis.XTick at 0x7f400cb6d908>,
#   <matplotlib.axis.XTick at 0x7f400cbded30>,
#   <matplotlib.axis.XTick at 0x7f400cb73278>,
#   <matplotlib.axis.XTick at 0x7f400cb737f0>,
#   <matplotlib.axis.XTick at 0x7f400cb73d68>,
#   <matplotlib.axis.XTick at 0x7f400cb7a320>,
#   <matplotlib.axis.XTick at 0x7f400cb7a898>,
#   <matplotlib.axis.XTick at 0x7f400cb7ae10>,
#   <matplotlib.axis.XTick at 0x7f400cb833c8>,
#   <matplotlib.axis.XTick at 0x7f400cb7a3c8>,
#   <matplotlib.axis.XTick at 0x7f400cb735f8>,
#   <matplotlib.axis.XTick at 0x7f400cb83710>,
#   <matplotlib.axis.XTick at 0x7f400cb83e48>,
#   <matplotlib.axis.XTick at 0x7f400cb8a400>,
#   <matplotlib.axis.XTick at 0x7f400cb8a978>,
#   <matplotlib.axis.XTick at 0x7f400cb8aef0>,
#   <matplotlib.axis.XTick at 0x7f400cb924a8>,
#   <matplotlib.axis.XTick at 0x7f400cb92a20>,
#   <matplotlib.axis.XTick at 0x7f400cb92e80>,
#   <matplotlib.axis.XTick at 0x7f400cb929e8>,
#   <matplotlib.axis.XTick at 0x7f400cb83f28>,
#   <matplotlib.axis.XTick at 0x7f400cb9a470>,
#   <matplotlib.axis.XTick at 0x7f400cb9a9e8>,
#   <matplotlib.axis.XTick at 0x7f400cb9af60>,
#   <matplotlib.axis.XTick at 0x7f400cba0518>,
#   <matplotlib.axis.XTick at 0x7f400cba0a90>,
#   <matplotlib.axis.XTick at 0x7f400cba70b8>,
#   <matplotlib.axis.XTick at 0x7f400cba75c0>,
#   <matplotlib.axis.XTick at 0x7f400cba0470>,
#   <matplotlib.axis.XTick at 0x7f400cb9a860>,
#   <matplotlib.axis.XTick at 0x7f400cba7780>,
#   <matplotlib.axis.XTick at 0x7f400cb2f0f0>,
#   <matplotlib.axis.XTick at 0x7f400cb2f5f8>,
#   <matplotlib.axis.XTick at 0x7f400cb2fb70>,
#   <matplotlib.axis.XTick at 0x7f400cb35160>,
#   <matplotlib.axis.XTick at 0x7f400cb356a0>,
#   <matplotlib.axis.XTick at 0x7f400cb35c18>,
#   <matplotlib.axis.XTick at 0x7f400cb3c1d0>,
#   <matplotlib.axis.XTick at 0x7f400cb35748>,
#   <matplotlib.axis.XTick at 0x7f400cb73cc0>,
#   <matplotlib.axis.XTick at 0x7f400cb3c668>,
#   <matplotlib.axis.XTick at 0x7f400cb3cbe0>,
#   <matplotlib.axis.XTick at 0x7f400cb44198>,
#   <matplotlib.axis.XTick at 0x7f400cb44710>,
#   <matplotlib.axis.XTick at 0x7f400cb44c88>,
#   <matplotlib.axis.XTick at 0x7f400cb4c240>,
#   <matplotlib.axis.XTick at 0x7f400cb4c7b8>,
#   <matplotlib.axis.XTick at 0x7f400cb44240>,
#   <matplotlib.axis.XTick at 0x7f400cb3cba8>,
#   <matplotlib.axis.XTick at 0x7f400cb83898>,
#   <matplotlib.axis.XTick at 0x7f400cc152b0>,
#   <matplotlib.axis.XTick at 0x7f400cb4c630>,
#   <matplotlib.axis.XTick at 0x7f400cb543c8>,
#   <matplotlib.axis.XTick at 0x7f400cb54940>,
#   <matplotlib.axis.XTick at 0x7f400cb54eb8>,
#   <matplotlib.axis.XTick at 0x7f400cb5a470>,
#   <matplotlib.axis.XTick at 0x7f400cb5a9e8>,
#   <matplotlib.axis.XTick at 0x7f400cb54f98>,
#   <matplotlib.axis.XTick at 0x7f400cb837b8>,
#   <matplotlib.axis.XTick at 0x7f400cb5a550>,
#   <matplotlib.axis.XTick at 0x7f400cb64438>,
#   <matplotlib.axis.XTick at 0x7f400cb649b0>,
#   <matplotlib.axis.XTick at 0x7f400cb64f28>,
#   <matplotlib.axis.XTick at 0x7f400cb694e0>,
#   <matplotlib.axis.XTick at 0x7f400cb69a58>,
#   <matplotlib.axis.XTick at 0x7f400cb69ba8>,
#   <matplotlib.axis.XTick at 0x7f400cb695c0>,
#   <matplotlib.axis.XTick at 0x7f400cb64828>,
#   <matplotlib.axis.XTick at 0x7f400caf0438>,
#   <matplotlib.axis.XTick at 0x7f400caf0b00>,
#   <matplotlib.axis.XTick at 0x7f400caf9128>,
#   <matplotlib.axis.XTick at 0x7f400caf9630>,
#   <matplotlib.axis.XTick at 0x7f400caf9ba8>,
#   <matplotlib.axis.XTick at 0x7f400cafe198>,
#   <matplotlib.axis.XTick at 0x7f400cafe6d8>,
#   <matplotlib.axis.XTick at 0x7f400cafec50>,
#   <matplotlib.axis.XTick at 0x7f400cafe7b8>,
#   <matplotlib.axis.XTick at 0x7f400caf9f98>,
#   <matplotlib.axis.XTick at 0x7f400cb06198>,
#   <matplotlib.axis.XTick at 0x7f400cb066a0>,
#   <matplotlib.axis.XTick at 0x7f400cb06c18>,
#   <matplotlib.axis.XTick at 0x7f400cb0e1d0>,
#   <matplotlib.axis.XTick at 0x7f400cb0e748>,
#   <matplotlib.axis.XTick at 0x7f400cb0ecc0>,
#   <matplotlib.axis.XTick at 0x7f400cb16278>,
#   <matplotlib.axis.XTick at 0x7f400cb0e278>,
#   <matplotlib.axis.XTick at 0x7f400cb06668>,
#   <matplotlib.axis.XTick at 0x7f400cb165c0>,
#   <matplotlib.axis.XTick at 0x7f400cb16cf8>,
#   <matplotlib.axis.XTick at 0x7f400cb1d2b0>,
#   <matplotlib.axis.XTick at 0x7f400cb1d828>,
#   <matplotlib.axis.XTick at 0x7f400cb1dda0>,
#   <matplotlib.axis.XTick at 0x7f400cb23358>,
#   <matplotlib.axis.XTick at 0x7f400cb238d0>,
#   <matplotlib.axis.XTick at 0x7f400cb23e48>,
#   <matplotlib.axis.XTick at 0x7f400cb239b0>,
#   <matplotlib.axis.XTick at 0x7f400cb1d8d0>,
#   <matplotlib.axis.XTick at 0x7f400caaa320>,
#   <matplotlib.axis.XTick at 0x7f400caaa898>,
#   <matplotlib.axis.XTick at 0x7f400caaae10>,
#   <matplotlib.axis.XTick at 0x7f400cab23c8>,
#   <matplotlib.axis.XTick at 0x7f400cab2940>,
#   <matplotlib.axis.XTick at 0x7f400cab2eb8>,
#   <matplotlib.axis.XTick at 0x7f400cab9470>,
#   <matplotlib.axis.XTick at 0x7f400cab2470>,
#   <matplotlib.axis.XTick at 0x7f400caaa6a0>,
#   <matplotlib.axis.XTick at 0x7f400cab97b8>,
#   <matplotlib.axis.XTick at 0x7f400cab9ef0>,
#   <matplotlib.axis.XTick at 0x7f400cac04a8>,
#   <matplotlib.axis.XTick at 0x7f400cac0a20>,
#   <matplotlib.axis.XTick at 0x7f400cac0e80>,
#   <matplotlib.axis.XTick at 0x7f400cac8550>,
#   <matplotlib.axis.XTick at 0x7f400cac8ac8>,
#   <matplotlib.axis.XTick at 0x7f400cad00f0>,
#   <matplotlib.axis.XTick at 0x7f400cac88d0>,
#   <matplotlib.axis.XTick at 0x7f400cab9e48>,
#   <matplotlib.axis.XTick at 0x7f400cad0518>,
#   <matplotlib.axis.XTick at 0x7f400cad0a90>,
#   <matplotlib.axis.XTick at 0x7f400cad70b8>,
#   <matplotlib.axis.XTick at 0x7f400cad75c0>,
#   <matplotlib.axis.XTick at 0x7f400cad7b38>,
#   <matplotlib.axis.XTick at 0x7f400cade160>,
#   <matplotlib.axis.XTick at 0x7f400cade668>,
#   <matplotlib.axis.XTick at 0x7f400cad73c8>,
#   <matplotlib.axis.XTick at 0x7f400cad05f8>,
#   <matplotlib.axis.XTick at 0x7f400caded68>,
#   <matplotlib.axis.XTick at 0x7f400cae6160>,
#   <matplotlib.axis.XTick at 0x7f400cae66a0>,
#   <matplotlib.axis.XTick at 0x7f400cae6c18>,
#   <matplotlib.axis.XTick at 0x7f400ca6b1d0>,
#   <matplotlib.axis.XTick at 0x7f400ca6b748>,
#   <matplotlib.axis.XTick at 0x7f400ca6bcc0>,
#   <matplotlib.axis.XTick at 0x7f400ca74278>,
#   <matplotlib.axis.XTick at 0x7f400ca6b828>,
#   <matplotlib.axis.XTick at 0x7f400cad0240>,
#   <matplotlib.axis.XTick at 0x7f400ca74710>,
#   <matplotlib.axis.XTick at 0x7f400ca74c88>,
#   <matplotlib.axis.XTick at 0x7f400ca7b240>,
#   <matplotlib.axis.XTick at 0x7f400ca7b7b8>,
#   <matplotlib.axis.XTick at 0x7f400ca7bd30>,
#   <matplotlib.axis.XTick at 0x7f400ca832e8>,
#   <matplotlib.axis.XTick at 0x7f400ca83860>,
#   <matplotlib.axis.XTick at 0x7f400ca83dd8>,
#   <matplotlib.axis.XTick at 0x7f400ca7bba8>,
#   <matplotlib.axis.XTick at 0x7f400ca74630>,
#   <matplotlib.axis.XTick at 0x7f400ca8b320>,
#   <matplotlib.axis.XTick at 0x7f400ca8b898>,
#   <matplotlib.axis.XTick at 0x7f400ca8be10>,
#   <matplotlib.axis.XTick at 0x7f400ca923c8>,
#   <matplotlib.axis.XTick at 0x7f400ca92940>,
#   <matplotlib.axis.XTick at 0x7f400ca92eb8>,
#   <matplotlib.axis.XTick at 0x7f400ca9a470>,
#   <matplotlib.axis.XTick at 0x7f400ca92a20>,
#   <matplotlib.axis.XTick at 0x7f400ca8b198>,
#   <matplotlib.axis.XTick at 0x7f400ca9a908>,
#   <matplotlib.axis.XTick at 0x7f400ca9ae80>,
#   <matplotlib.axis.XTick at 0x7f400caa0438>,
#   <matplotlib.axis.XTick at 0x7f400caa09b0>,
#   <matplotlib.axis.XTick at 0x7f400caa0f28>,
#   <matplotlib.axis.XTick at 0x7f400caa74e0>,
#   <matplotlib.axis.XTick at 0x7f400caa7a58>,
#   <matplotlib.axis.XTick at 0x7f400caa7ba8>,
#   <matplotlib.axis.XTick at 0x7f400caa0908>,
#   <matplotlib.axis.XTick at 0x7f400ca9a2e8>,
#   <matplotlib.axis.XTick at 0x7f400cab9a90>,
#   <matplotlib.axis.XTick at 0x7f400caaa208>,
#   <matplotlib.axis.XTick at 0x7f400ca2f668>,
#   <matplotlib.axis.XTick at 0x7f400ca2fbe0>,
#   <matplotlib.axis.XTick at 0x7f400ca36198>,
#   <matplotlib.axis.XTick at 0x7f400ca36710>,
#   <matplotlib.axis.XTick at 0x7f400ca36c88>,
#   <matplotlib.axis.XTick at 0x7f400ca36d68>,
#   <matplotlib.axis.XTick at 0x7f400ca2f4e0>,
#   <matplotlib.axis.XTick at 0x7f400ca3d0f0>,
#   <matplotlib.axis.XTick at 0x7f400ca3d6d8>,
#   <matplotlib.axis.XTick at 0x7f400ca3dc50>,
#   <matplotlib.axis.XTick at 0x7f400ca45208>,
#   <matplotlib.axis.XTick at 0x7f400ca45780>,
#   <matplotlib.axis.XTick at 0x7f400ca45cf8>,
#   <matplotlib.axis.XTick at 0x7f400ca4b2b0>,
#   <matplotlib.axis.XTick at 0x7f400ca455f8>,
#   <matplotlib.axis.XTick at 0x7f400ca3d630>,
#   <matplotlib.axis.XTick at 0x7f400ca4b400>,
#   <matplotlib.axis.XTick at 0x7f400ca4bda0>,
#   <matplotlib.axis.XTick at 0x7f400ca52358>,
#   <matplotlib.axis.XTick at 0x7f400ca528d0>,
#   <matplotlib.axis.XTick at 0x7f400ca52e48>,
#   <matplotlib.axis.XTick at 0x7f400ca5a400>,
#   <matplotlib.axis.XTick at 0x7f400ca5a978>,
#   <matplotlib.axis.XTick at 0x7f400ca5aef0>,
#   <matplotlib.axis.XTick at 0x7f400ca5aa58>,
#   <matplotlib.axis.XTick at 0x7f400ca52400>,
#   <matplotlib.axis.XTick at 0x7f400ca613c8>,
#   <matplotlib.axis.XTick at 0x7f400ca61940>,
#   <matplotlib.axis.XTick at 0x7f400ca61eb8>,
#   <matplotlib.axis.XTick at 0x7f400ca68470>,
#   <matplotlib.axis.XTick at 0x7f400ca689e8>,
#   <matplotlib.axis.XTick at 0x7f400ca68f60>,
#   <matplotlib.axis.XTick at 0x7f400c9ef518>,
#   <matplotlib.axis.XTick at 0x7f400ca683c8>,
#   <matplotlib.axis.XTick at 0x7f400ca617b8>,
#   <matplotlib.axis.XTick at 0x7f400c9ef6d8>,
#   <matplotlib.axis.XTick at 0x7f400c9efe80>,
#   <matplotlib.axis.XTick at 0x7f400c9f7550>,
#   <matplotlib.axis.XTick at 0x7f400c9f7ac8>,
#   <matplotlib.axis.XTick at 0x7f400c9fe0f0>,
#   <matplotlib.axis.XTick at 0x7f400c9fe5f8>,
#   <matplotlib.axis.XTick at 0x7f400c9feb70>,
#   <matplotlib.axis.XTick at 0x7f400ca05160>,
#   <matplotlib.axis.XTick at 0x7f400c9fe9e8>,
#   <matplotlib.axis.XTick at 0x7f400c9efda0>,
#   <matplotlib.axis.XTick at 0x7f400ca055c0>,
#   <matplotlib.axis.XTick at 0x7f400ca05b38>,
#   <matplotlib.axis.XTick at 0x7f400ca0c160>,
#   <matplotlib.axis.XTick at 0x7f400ca0c668>,
#   <matplotlib.axis.XTick at 0x7f400ca0cbe0>,
#   <matplotlib.axis.XTick at 0x7f400ca15198>,
#   <matplotlib.axis.XTick at 0x7f400ca15710>,
#   <matplotlib.axis.XTick at 0x7f400ca0c470>,
#   <matplotlib.axis.XTick at 0x7f400ca056a0>,
#   <matplotlib.axis.XTick at 0x7f400ca15e10>,
#   <matplotlib.axis.XTick at 0x7f400ca1c1d0>,
#   <matplotlib.axis.XTick at 0x7f400ca1c748>,
#   <matplotlib.axis.XTick at 0x7f400ca1ccc0>,
#   <matplotlib.axis.XTick at 0x7f400ca23278>,
#   <matplotlib.axis.XTick at 0x7f400ca237f0>,
#   <matplotlib.axis.XTick at 0x7f400ca23d68>,
#   <matplotlib.axis.XTick at 0x7f400c9ab320>,
#   <matplotlib.axis.XTick at 0x7f400ca238d0>,
#   <matplotlib.axis.XTick at 0x7f400ca054e0>,
#   <matplotlib.axis.XTick at 0x7f400c9ab7b8>,
#   <matplotlib.axis.XTick at 0x7f400c9abd30>,
#   <matplotlib.axis.XTick at 0x7f400c9b12e8>,
#   <matplotlib.axis.XTick at 0x7f400c9b1860>,
#   <matplotlib.axis.XTick at 0x7f400c9b1dd8>,
#   <matplotlib.axis.XTick at 0x7f400c9b9390>,
#   <matplotlib.axis.XTick at 0x7f400c9b9908>,
#   <matplotlib.axis.XTick at 0x7f400c9b9e80>,
#   <matplotlib.axis.XTick at 0x7f400c9b1908>,
#   <matplotlib.axis.XTick at 0x7f400ca15860>,
#   <matplotlib.axis.XTick at 0x7f400c9bf3c8>,
#   <matplotlib.axis.XTick at 0x7f400c9bf940>,
#   <matplotlib.axis.XTick at 0x7f400c9bfeb8>,
#   <matplotlib.axis.XTick at 0x7f400c9c8470>,
#   <matplotlib.axis.XTick at 0x7f400c9c89e8>,
#   <matplotlib.axis.XTick at 0x7f400c9c8f60>,
#   <matplotlib.axis.XTick at 0x7f400c9cf518>,
#   <matplotlib.axis.XTick at 0x7f400c9c89b0>,
#   <matplotlib.axis.XTick at 0x7f400ca1c6a0>,
#   <matplotlib.axis.XTick at 0x7f400c9cf9b0>,
#   <matplotlib.axis.XTick at 0x7f400c9cff28>,
#   <matplotlib.axis.XTick at 0x7f400c9d74e0>,
#   <matplotlib.axis.XTick at 0x7f400c9d7a58>,
#   <matplotlib.axis.XTick at 0x7f400c9d7ba8>,
#   <matplotlib.axis.XTick at 0x7f400c9de588>,
#   <matplotlib.axis.XTick at 0x7f400c9deb00>,
#   <matplotlib.axis.XTick at 0x7f400c9de630>,
#   <matplotlib.axis.XTick at 0x7f400c9d7a20>,
#   <matplotlib.axis.XTick at 0x7f400c9bf748>,
#   <matplotlib.axis.XTick at 0x7f400c9e45c0>,
#   <matplotlib.axis.XTick at 0x7f400c9e4b38>,
#   <matplotlib.axis.XTick at 0x7f400c96b160>,
#   <matplotlib.axis.XTick at 0x7f400c96b668>,
#   <matplotlib.axis.XTick at 0x7f400c96bbe0>,
#   <matplotlib.axis.XTick at 0x7f400c973198>,
#   <matplotlib.axis.XTick at 0x7f400c973710>,
#   <matplotlib.axis.XTick at 0x7f400c96ba58>,
#   <matplotlib.axis.XTick at 0x7f400c9bf1d0>,
#   <matplotlib.axis.XTick at 0x7f400c973ba8>,
#   <matplotlib.axis.XTick at 0x7f400c97b198>,
#   <matplotlib.axis.XTick at 0x7f400c97b6d8>,
#   <matplotlib.axis.XTick at 0x7f400c97bc50>,
#   <matplotlib.axis.XTick at 0x7f400c981208>,
#   <matplotlib.axis.XTick at 0x7f400c981780>,
#   <matplotlib.axis.XTick at 0x7f400c981cf8>,
#   <matplotlib.axis.XTick at 0x7f400c981588>,
#   <matplotlib.axis.XTick at 0x7f400c97b7b8>,
#   <matplotlib.axis.XTick at 0x7f400c9e4668>,
#   <matplotlib.axis.XTick at 0x7f400ca15b00>,
#   <matplotlib.axis.XTick at 0x7f400c989160>,
#   <matplotlib.axis.XTick at 0x7f400c989908>,
#   <matplotlib.axis.XTick at 0x7f400c989e80>,
#   <matplotlib.axis.XTick at 0x7f400c992438>,
#   <matplotlib.axis.XTick at 0x7f400c9929b0>,
#   <matplotlib.axis.XTick at 0x7f400c992f28>,
#   <matplotlib.axis.XTick at 0x7f400c992e80>,
#   <matplotlib.axis.XTick at 0x7f400c9891d0>,
#   <matplotlib.axis.XTick at 0x7f400c998128>,
#   <matplotlib.axis.XTick at 0x7f400c998978>,
#   <matplotlib.axis.XTick at 0x7f400c998ef0>,
#   <matplotlib.axis.XTick at 0x7f400c99f4a8>,
#   <matplotlib.axis.XTick at 0x7f400c99fa20>,
#   <matplotlib.axis.XTick at 0x7f400c99fe80>,
#   <matplotlib.axis.XTick at 0x7f400c9a7550>,
#   <matplotlib.axis.XTick at 0x7f400c99f588>,
#   <matplotlib.axis.XTick at 0x7f400c998780>,
#   <matplotlib.axis.XTick at 0x7f400c9a7d68>,
#   <matplotlib.axis.XTick at 0x7f400c92d0f0>,
#   <matplotlib.axis.XTick at 0x7f400c92d5f8>,
#   <matplotlib.axis.XTick at 0x7f400c92db70>,
#   <matplotlib.axis.XTick at 0x7f400c934160>,
#   <matplotlib.axis.XTick at 0x7f400c9346a0>,
#   <matplotlib.axis.XTick at 0x7f400c934c18>,
#   <matplotlib.axis.XTick at 0x7f400c93c1d0>,
#   <matplotlib.axis.XTick at 0x7f400c934748>,
#   <matplotlib.axis.XTick at 0x7f400c998048>,
#   <matplotlib.axis.XTick at 0x7f400c93c668>,
#   <matplotlib.axis.XTick at 0x7f400c93cbe0>,
#   <matplotlib.axis.XTick at 0x7f400c944198>,
#   <matplotlib.axis.XTick at 0x7f400c944710>,
#   <matplotlib.axis.XTick at 0x7f400c944c88>,
#   <matplotlib.axis.XTick at 0x7f400c94b240>,
#   <matplotlib.axis.XTick at 0x7f400c94b7b8>,
#   <matplotlib.axis.XTick at 0x7f400c944240>,
#   <matplotlib.axis.XTick at 0x7f400c93c630>,
#   <matplotlib.axis.XTick at 0x7f400c94bf60>,
#   <matplotlib.axis.XTick at 0x7f400c954278>,
#   <matplotlib.axis.XTick at 0x7f400c9547f0>,
#   <matplotlib.axis.XTick at 0x7f400c954d68>,
#   <matplotlib.axis.XTick at 0x7f400c95c320>,
#   <matplotlib.axis.XTick at 0x7f400c95c898>,
#   <matplotlib.axis.XTick at 0x7f400c95ce10>,
#   <matplotlib.axis.XTick at 0x7f400c9623c8>,
#   <matplotlib.axis.XTick at 0x7f400c95c978>,
#   <matplotlib.axis.XTick at 0x7f400c954898>,
#   <matplotlib.axis.XTick at 0x7f400c962860>,
#   <matplotlib.axis.XTick at 0x7f400c962dd8>,
#   <matplotlib.axis.XTick at 0x7f400c969390>,
#   <matplotlib.axis.XTick at 0x7f400c969908>,
#   <matplotlib.axis.XTick at 0x7f400c969e80>,
#   <matplotlib.axis.XTick at 0x7f400c8f0438>,
#   <matplotlib.axis.XTick at 0x7f400c8f09b0>,
#   <matplotlib.axis.XTick at 0x7f400c8f0f28>,
#   <matplotlib.axis.XTick at 0x7f400c9699b0>,
#   <matplotlib.axis.XTick at 0x7f400c94be80>,
#   <matplotlib.axis.XTick at 0x7f400c8f7470>,
#   <matplotlib.axis.XTick at 0x7f400c8f79e8>,
#   <matplotlib.axis.XTick at 0x7f400c8f7f60>,
#   <matplotlib.axis.XTick at 0x7f400c8fe518>,
#   <matplotlib.axis.XTick at 0x7f400c8fea90>,
#   <matplotlib.axis.XTick at 0x7f400c9050b8>,
#   <matplotlib.axis.XTick at 0x7f400c9055c0>,
#   <matplotlib.axis.XTick at 0x7f400c8fea58>,
#   <matplotlib.axis.XTick at 0x7f400c9545f8>,
#   <matplotlib.axis.XTick at 0x7f400c905a58>,
#   <matplotlib.axis.XTick at 0x7f400c905ba8>,
#   <matplotlib.axis.XTick at 0x7f400c90d588>,
#   <matplotlib.axis.XTick at 0x7f400c90db00>,
#   <matplotlib.axis.XTick at 0x7f400c914128>,
#   <matplotlib.axis.XTick at 0x7f400c914630>,
#   <matplotlib.axis.XTick at 0x7f400c914ba8>,
#   <matplotlib.axis.XTick at 0x7f400c914588>,
#   <matplotlib.axis.XTick at 0x7f400c90d978>,
#   <matplotlib.axis.XTick at 0x7f400c8fe5c0>,
#   <matplotlib.axis.XTick at 0x7f400c91d668>,
#   <matplotlib.axis.XTick at 0x7f400c91dbe0>,
#   <matplotlib.axis.XTick at 0x7f400c924198>,
#   <matplotlib.axis.XTick at 0x7f400c924710>,
#   <matplotlib.axis.XTick at 0x7f400c924c88>,
#   <matplotlib.axis.XTick at 0x7f400c8ab240>,
#   <matplotlib.axis.XTick at 0x7f400c8ab7b8>,
#   <matplotlib.axis.XTick at 0x7f400c9247f0>,
#   <matplotlib.axis.XTick at 0x7f400c905588>,
#   <matplotlib.axis.XTick at 0x7f400c8abc50>,
#   <matplotlib.axis.XTick at 0x7f400c8b2208>,
#   <matplotlib.axis.XTick at 0x7f400c8b2780>,
#   <matplotlib.axis.XTick at 0x7f400c8b2cf8>,
#   <matplotlib.axis.XTick at 0x7f400c8b82b0>,
#   <matplotlib.axis.XTick at 0x7f400c8b8828>,
#   <matplotlib.axis.XTick at 0x7f400c8b8da0>,
#   <matplotlib.axis.XTick at 0x7f400c8b8358>,
#   <matplotlib.axis.XTick at 0x7f400c8b2588>,
#   <matplotlib.axis.XTick at 0x7f400c8c0358>,
#   <matplotlib.axis.XTick at 0x7f400c8c0860>,
#   <matplotlib.axis.XTick at 0x7f400c8c0dd8>,
#   <matplotlib.axis.XTick at 0x7f400c8c7390>,
#   <matplotlib.axis.XTick at 0x7f400c8c7908>,
#   <matplotlib.axis.XTick at 0x7f400c8c7e80>,
#   <matplotlib.axis.XTick at 0x7f400c8ce438>,
#   <matplotlib.axis.XTick at 0x7f400c8ce9b0>,
#   <matplotlib.axis.XTick at 0x7f400c8c79e8>,
#   <matplotlib.axis.XTick at 0x7f400c905a20>,
#   <matplotlib.axis.XTick at 0x7f400c8cee48>,
#   <matplotlib.axis.XTick at 0x7f400c8d6400>,
#   <matplotlib.axis.XTick at 0x7f400c8d6978>,
#   <matplotlib.axis.XTick at 0x7f400c8d6ef0>,
#   <matplotlib.axis.XTick at 0x7f400c8dd4a8>,
#   <matplotlib.axis.XTick at 0x7f400c8dda20>,
#   <matplotlib.axis.XTick at 0x7f400c8dde80>,
#   <matplotlib.axis.XTick at 0x7f400c8dd400>,
#   <matplotlib.axis.XTick at 0x7f400c8d67f0>,
#   <matplotlib.axis.XTick at 0x7f400c8c0400>,
#   <matplotlib.axis.XTick at 0x7f400c94be10>,
#   <matplotlib.axis.XTick at 0x7f400c8e3198>,
#   <matplotlib.axis.XTick at 0x7f400c8e3ba8>,
#   <matplotlib.axis.XTick at 0x7f400c86e198>,
#   <matplotlib.axis.XTick at 0x7f400c86e6d8>,
#   <matplotlib.axis.XTick at 0x7f400c86ec50>,
#   <matplotlib.axis.XTick at 0x7f400c874208>,
#   <matplotlib.axis.XTick at 0x7f400c86ecf8>,
#   <matplotlib.axis.XTick at 0x7f400c94bb38>,
#   <matplotlib.axis.XTick at 0x7f400c8742b0>,
#   <matplotlib.axis.XTick at 0x7f400c874c18>,
#   <matplotlib.axis.XTick at 0x7f400c87c1d0>,
#   <matplotlib.axis.XTick at 0x7f400c87c748>,
#   <matplotlib.axis.XTick at 0x7f400c87ccc0>,
#   <matplotlib.axis.XTick at 0x7f400c881278>,
#   <matplotlib.axis.XTick at 0x7f400c8817f0>,
#   <matplotlib.axis.XTick at 0x7f400c881d68>,
#   <matplotlib.axis.XTick at 0x7f400c87cc18>,
#   <matplotlib.axis.XTick at 0x7f400c8741d0>,
#   <matplotlib.axis.XTick at 0x7f400c889320>,
#   <matplotlib.axis.XTick at 0x7f400c889898>,
#   <matplotlib.axis.XTick at 0x7f400c889e10>,
#   <matplotlib.axis.XTick at 0x7f400c8903c8>,
#   <matplotlib.axis.XTick at 0x7f400c890940>,
#   <matplotlib.axis.XTick at 0x7f400c890eb8>,
#   <matplotlib.axis.XTick at 0x7f400c897470>,
#   <matplotlib.axis.XTick at 0x7f400c890a20>,
#   <matplotlib.axis.XTick at 0x7f400c889198>,
#   <matplotlib.axis.XTick at 0x7f400c897908>,
#   <matplotlib.axis.XTick at 0x7f400c897e80>,
#   <matplotlib.axis.XTick at 0x7f400c8a0438>,
#   <matplotlib.axis.XTick at 0x7f400c8a09b0>,
#   <matplotlib.axis.XTick at 0x7f400c8a0f28>,
#   <matplotlib.axis.XTick at 0x7f400c8a64e0>,
#   <matplotlib.axis.XTick at 0x7f400c8a6a58>,
#   <matplotlib.axis.XTick at 0x7f400c8a6ba8>,
#   <matplotlib.axis.XTick at 0x7f400c8a0908>,
#   <matplotlib.axis.XTick at 0x7f400c889128>,
#   <matplotlib.axis.XTick at 0x7f400c82d518>,
#   <matplotlib.axis.XTick at 0x7f400c82da90>,
#   <matplotlib.axis.XTick at 0x7f400c8350b8>,
#   <matplotlib.axis.XTick at 0x7f400c8355c0>,
#   <matplotlib.axis.XTick at 0x7f400c835b38>,
#   <matplotlib.axis.XTick at 0x7f400c83d160>,
#   <matplotlib.axis.XTick at 0x7f400c83d668>,
#   <matplotlib.axis.XTick at 0x7f400c8359b0>,
#   <matplotlib.axis.XTick at 0x7f400c889278>,
#   <matplotlib.axis.XTick at 0x7f400c83db00>,
#   <matplotlib.axis.XTick at 0x7f400c843128>,
#   <matplotlib.axis.XTick at 0x7f400c843630>,
#   <matplotlib.axis.XTick at 0x7f400c843ba8>,
#   <matplotlib.axis.XTick at 0x7f400c84b198>,
#   <matplotlib.axis.XTick at 0x7f400c84b6d8>,
#   <matplotlib.axis.XTick at 0x7f400c84bc50>,
#   <matplotlib.axis.XTick at 0x7f400c84b6a0>,
#   <matplotlib.axis.XTick at 0x7f400c8436d8>,
#   <matplotlib.axis.XTick at 0x7f400c835588>,
#   <matplotlib.axis.XTick at 0x7f400c852710>,
#   <matplotlib.axis.XTick at 0x7f400c852c88>,
#   <matplotlib.axis.XTick at 0x7f400c85a240>,
#   <matplotlib.axis.XTick at 0x7f400c85a7b8>,
#   <matplotlib.axis.XTick at 0x7f400c85ad30>,
#   <matplotlib.axis.XTick at 0x7f400c8602e8>,
#   <matplotlib.axis.XTick at 0x7f400c860860>,
#   <matplotlib.axis.XTick at 0x7f400c85a898>,
#   <matplotlib.axis.XTick at 0x7f400c8a6358>,
#   <matplotlib.axis.XTick at 0x7f400c860cf8>,
#   <matplotlib.axis.XTick at 0x7f400c8682b0>,
#   <matplotlib.axis.XTick at 0x7f400c868828>,
#   <matplotlib.axis.XTick at 0x7f400c868da0>,
#   <matplotlib.axis.XTick at 0x7f400c7ee358>,
#   <matplotlib.axis.XTick at 0x7f400c7ee8d0>,
#   <matplotlib.axis.XTick at 0x7f400c7eee48>,
#   <matplotlib.axis.XTick at 0x7f400c7ee400>,
#   <matplotlib.axis.XTick at 0x7f400c8687f0>,
#   <matplotlib.axis.XTick at 0x7f400c7f5400>,
#   <matplotlib.axis.XTick at 0x7f400c7f5908>,
#   <matplotlib.axis.XTick at 0x7f400c7f5e80>,
#   <matplotlib.axis.XTick at 0x7f400c7fd438>,
#   <matplotlib.axis.XTick at 0x7f400c7fd9b0>,
#   <matplotlib.axis.XTick at 0x7f400c7fdf28>,
#   <matplotlib.axis.XTick at 0x7f400c8044e0>,
#   <matplotlib.axis.XTick at 0x7f400c804a58>,
#   <matplotlib.axis.XTick at 0x7f400c7fd908>,
#   <matplotlib.axis.XTick at 0x7f400c868358>,
#   <matplotlib.axis.XTick at 0x7f400c804ef0>,
#   <matplotlib.axis.XTick at 0x7f400c80f4a8>,
#   <matplotlib.axis.XTick at 0x7f400c80fa20>,
#   <matplotlib.axis.XTick at 0x7f400c80fe80>,
#   <matplotlib.axis.XTick at 0x7f400c815550>,
#   <matplotlib.axis.XTick at 0x7f400c815ac8>,
#   <matplotlib.axis.XTick at 0x7f400c81c0f0>,
#   <matplotlib.axis.XTick at 0x7f400c815518>,
#   <matplotlib.axis.XTick at 0x7f400c80f550>,
#   <matplotlib.axis.XTick at 0x7f400c81c4a8>,
#   <matplotlib.axis.XTick at 0x7f400c81cb00>,
#   <matplotlib.axis.XTick at 0x7f400c823128>,
#   <matplotlib.axis.XTick at 0x7f400c823630>,
#   <matplotlib.axis.XTick at 0x7f400c823ba8>,
#   <matplotlib.axis.XTick at 0x7f400c7ab198>,
#   <matplotlib.axis.XTick at 0x7f400c7ab6d8>,
#   <matplotlib.axis.XTick at 0x7f400c7abc50>,
#   <matplotlib.axis.XTick at 0x7f400c7ab7b8>,
#   <matplotlib.axis.XTick at 0x7f400c823f98>,
#   <matplotlib.axis.XTick at 0x7f400c7b1198>,
#   <matplotlib.axis.XTick at 0x7f400c7b16a0>,
#   <matplotlib.axis.XTick at 0x7f400c7b1c18>,
#   <matplotlib.axis.XTick at 0x7f400c7b91d0>,
#   <matplotlib.axis.XTick at 0x7f400c7b9748>,
#   <matplotlib.axis.XTick at 0x7f400c7b9cc0>,
#   <matplotlib.axis.XTick at 0x7f400c7c0278>,
#   <matplotlib.axis.XTick at 0x7f400c7b9278>,
#   <matplotlib.axis.XTick at 0x7f400c7b9048>,
#   <matplotlib.axis.XTick at 0x7f400c81c400>,
#   <matplotlib.axis.XTick at 0x7f400c8a6e48>,
#   <matplotlib.axis.XTick at 0x7f400c7c0a20>,
#   <matplotlib.axis.XTick at 0x7f400c7c0e48>,
#   <matplotlib.axis.XTick at 0x7f400c7c6400>,
#   <matplotlib.axis.XTick at 0x7f400c7c6978>,
#   <matplotlib.axis.XTick at 0x7f400c7c6ef0>,
#   <matplotlib.axis.XTick at 0x7f400c7cc4a8>,
#   <matplotlib.axis.XTick at 0x7f400c7c6fd0>,
#   <matplotlib.axis.XTick at 0x7f400c8a6f28>,
#   <matplotlib.axis.XTick at 0x7f400c7cc588>,
#   <matplotlib.axis.XTick at 0x7f400c7cceb8>,
#   <matplotlib.axis.XTick at 0x7f400c7d6470>,
#   <matplotlib.axis.XTick at 0x7f400c7d69e8>,
#   <matplotlib.axis.XTick at 0x7f400c7d6f60>,
#   <matplotlib.axis.XTick at 0x7f400c7de518>,
#   <matplotlib.axis.XTick at 0x7f400c7dea90>,
#   <matplotlib.axis.XTick at 0x7f400c7de908>,
#   <matplotlib.axis.XTick at 0x7f400c7d6940>,
#   <matplotlib.axis.XTick at 0x7f400c7c06a0>,
#   <matplotlib.axis.XTick at 0x7f400c7e45c0>,
#   <matplotlib.axis.XTick at 0x7f400c7e4b38>,
#   <matplotlib.axis.XTick at 0x7f400c76c160>,
#   <matplotlib.axis.XTick at 0x7f400c76c668>,
#   <matplotlib.axis.XTick at 0x7f400c76cbe0>,
#   <matplotlib.axis.XTick at 0x7f400c773198>,
#   <matplotlib.axis.XTick at 0x7f400c773710>,
#   <matplotlib.axis.XTick at 0x7f400c76ca58>,
#   <matplotlib.axis.XTick at 0x7f400c881e48>,
#   <matplotlib.axis.XTick at 0x7f400c773ba8>,
#   <matplotlib.axis.XTick at 0x7f400c779198>,
#   <matplotlib.axis.XTick at 0x7f400c7796d8>,
#   <matplotlib.axis.XTick at 0x7f400c779c50>,
#   <matplotlib.axis.XTick at 0x7f400c781208>,
#   <matplotlib.axis.XTick at 0x7f400c781780>,
#   <matplotlib.axis.XTick at 0x7f400c781cf8>,
#   <matplotlib.axis.XTick at 0x7f400c781588>,
#   <matplotlib.axis.XTick at 0x7f400c7797b8>,
#   <matplotlib.axis.XTick at 0x7f400c83d9e8>,
#   <matplotlib.axis.XTick at 0x7f400c7887b8>,
#   <matplotlib.axis.XTick at 0x7f400c788d30>,
#   <matplotlib.axis.XTick at 0x7f400c78f2e8>,
#   <matplotlib.axis.XTick at 0x7f400c78f860>,
#   <matplotlib.axis.XTick at 0x7f400c78fdd8>,
#   <matplotlib.axis.XTick at 0x7f400c796390>,
#   <matplotlib.axis.XTick at 0x7f400c796908>,
#   <matplotlib.axis.XTick at 0x7f400c78f940>,
#   <matplotlib.axis.XTick at 0x7f400c7d6518>,
#   <matplotlib.axis.XTick at 0x7f400c796da0>,
#   <matplotlib.axis.XTick at 0x7f400c79f358>,
#   <matplotlib.axis.XTick at 0x7f400c79f8d0>,
#   <matplotlib.axis.XTick at 0x7f400c79fe48>,
#   <matplotlib.axis.XTick at 0x7f400c7a6400>,
#   <matplotlib.axis.XTick at 0x7f400c7a6978>,
#   <matplotlib.axis.XTick at 0x7f400c7a6ef0>,
#   <matplotlib.axis.XTick at 0x7f400c7a64a8>,
#   <matplotlib.axis.XTick at 0x7f400c79f898>,
#   <matplotlib.axis.XTick at 0x7f400c72e4a8>,
#   <matplotlib.axis.XTick at 0x7f400c72e9b0>,
#   <matplotlib.axis.XTick at 0x7f400c72ef28>,
#   <matplotlib.axis.XTick at 0x7f400c7354e0>,
#   <matplotlib.axis.XTick at 0x7f400c735a58>,
#   <matplotlib.axis.XTick at 0x7f400c735ba8>,
#   <matplotlib.axis.XTick at 0x7f400c73c588>,
#   <matplotlib.axis.XTick at 0x7f400c73cb00>,
#   <matplotlib.axis.XTick at 0x7f400c735a20>,
#   <matplotlib.axis.XTick at 0x7f400c79f438>,
#   <matplotlib.axis.XTick at 0x7f400c73c400>,
#   <matplotlib.axis.XTick at 0x7f400c744550>,
#   <matplotlib.axis.XTick at 0x7f400c744ac8>,
#   <matplotlib.axis.XTick at 0x7f400c74a0f0>,
#   <matplotlib.axis.XTick at 0x7f400c74a5f8>,
#   <matplotlib.axis.XTick at 0x7f400c74ab70>,
#   <matplotlib.axis.XTick at 0x7f400c752160>,
#   <matplotlib.axis.XTick at 0x7f400c74a400>,
#   <matplotlib.axis.XTick at 0x7f400c744630>,
#   <matplotlib.axis.XTick at 0x7f400c752550>,
#   <matplotlib.axis.XTick at 0x7f400c752ba8>,
#   <matplotlib.axis.XTick at 0x7f400c75a198>,
#   <matplotlib.axis.XTick at 0x7f400c75a6d8>,
#   <matplotlib.axis.XTick at 0x7f400c75ac50>,
#   <matplotlib.axis.XTick at 0x7f400c761208>,
#   <matplotlib.axis.XTick at 0x7f400c761780>,
#   <matplotlib.axis.XTick at 0x7f400c761cf8>,
#   <matplotlib.axis.XTick at 0x7f400c761860>,
#   <matplotlib.axis.XTick at 0x7f400c75aa58>,
#   <matplotlib.axis.XTick at 0x7f400c768208>,
#   <matplotlib.axis.XTick at 0x7f400c768748>,
#   <matplotlib.axis.XTick at 0x7f400c768cc0>,
#   <matplotlib.axis.XTick at 0x7f400c6ef278>,
#   <matplotlib.axis.XTick at 0x7f400c6ef7f0>,
#   <matplotlib.axis.XTick at 0x7f400c6efd68>,
#   <matplotlib.axis.XTick at 0x7f400c6f6320>,
#   <matplotlib.axis.XTick at 0x7f400c6ef320>,
#   <matplotlib.axis.XTick at 0x7f400c768550>,
#   <matplotlib.axis.XTick at 0x7f400c6f6668>,
#   <matplotlib.axis.XTick at 0x7f400c6f6da0>,
#   <matplotlib.axis.XTick at 0x7f400c6fd358>,
#   <matplotlib.axis.XTick at 0x7f400c6fd8d0>,
#   <matplotlib.axis.XTick at 0x7f400c6fde48>,
#   <matplotlib.axis.XTick at 0x7f400c704400>,
#   <matplotlib.axis.XTick at 0x7f400c704978>,
#   <matplotlib.axis.XTick at 0x7f400c704ef0>,
#   <matplotlib.axis.XTick at 0x7f400c704a58>,
#   <matplotlib.axis.XTick at 0x7f400c6fd978>,
#   <matplotlib.axis.XTick at 0x7f400c70d3c8>,
#   <matplotlib.axis.XTick at 0x7f400c70d940>,
#   <matplotlib.axis.XTick at 0x7f400c70deb8>,
#   <matplotlib.axis.XTick at 0x7f400c713470>,
#   <matplotlib.axis.XTick at 0x7f400c7139e8>,
#   <matplotlib.axis.XTick at 0x7f400c713f60>,
#   <matplotlib.axis.XTick at 0x7f400c71b518>,
#   <matplotlib.axis.XTick at 0x7f400c7133c8>,
#   <matplotlib.axis.XTick at 0x7f400c70dd30>,
#   <matplotlib.axis.XTick at 0x7f400c7680b8>,
#   <matplotlib.axis.XTick at 0x7f400c773b00>,
#   <matplotlib.axis.XTick at 0x7f400c71b5f8>,
#   <matplotlib.axis.XTick at 0x7f400c723160>,
#   <matplotlib.axis.XTick at 0x7f400c7236a0>,
#   <matplotlib.axis.XTick at 0x7f400c723c18>,
#   <matplotlib.axis.XTick at 0x7f400c6aa1d0>,
#   <matplotlib.axis.XTick at 0x7f400c6aa748>,
#   <matplotlib.axis.XTick at 0x7f400c723cc0>,
#   <matplotlib.axis.XTick at 0x7f400c7525f8>,
#   <matplotlib.axis.XTick at 0x7f400c6aa278>,
#   <matplotlib.axis.XTick at 0x7f400c6b0198>,
#   <matplotlib.axis.XTick at 0x7f400c6b0710>,
#   <matplotlib.axis.XTick at 0x7f400c6b0c88>,
#   <matplotlib.axis.XTick at 0x7f400c6b8240>,
#   <matplotlib.axis.XTick at 0x7f400c6b87b8>,
#   <matplotlib.axis.XTick at 0x7f400c6b8d30>,
#   <matplotlib.axis.XTick at 0x7f400c6b8780>,
#   <matplotlib.axis.XTick at 0x7f400c6b07b8>,
#   <matplotlib.axis.XTick at 0x7f400c6aaf60>,
#   <matplotlib.axis.XTick at 0x7f400c6bf860>,
#   <matplotlib.axis.XTick at 0x7f400c6bfdd8>,
#   <matplotlib.axis.XTick at 0x7f400c6c6390>,
#   <matplotlib.axis.XTick at 0x7f400c6c6908>,
#   <matplotlib.axis.XTick at 0x7f400c6c6e80>,
#   <matplotlib.axis.XTick at 0x7f400c6cf438>,
#   <matplotlib.axis.XTick at 0x7f400c6cf9b0>,
#   <matplotlib.axis.XTick at 0x7f400c6c69e8>,
#   <matplotlib.axis.XTick at 0x7f400c6f6d68>,
#   <matplotlib.axis.XTick at 0x7f400c6cfe48>,
#   <matplotlib.axis.XTick at 0x7f400c6d7400>,
#   <matplotlib.axis.XTick at 0x7f400c6d7978>,
#   <matplotlib.axis.XTick at 0x7f400c6d7ef0>,
#   <matplotlib.axis.XTick at 0x7f400c6de4a8>,
#   <matplotlib.axis.XTick at 0x7f400c6dea20>,
#   <matplotlib.axis.XTick at 0x7f400c6dee80>,
#   <matplotlib.axis.XTick at 0x7f400c6de400>,
#   <matplotlib.axis.XTick at 0x7f400c6d77f0>,
#   <matplotlib.axis.XTick at 0x7f400c6e5438>,
#   <matplotlib.axis.XTick at 0x7f400c6e5a58>,
#   <matplotlib.axis.XTick at 0x7f400c6e5ba8>,
#   <matplotlib.axis.XTick at 0x7f400c66c588>,
#   <matplotlib.axis.XTick at 0x7f400c66cb00>,
#   <matplotlib.axis.XTick at 0x7f400c670128>,
#   <matplotlib.axis.XTick at 0x7f400c670630>,
#   <matplotlib.axis.XTick at 0x7f400c670ba8>,
#   <matplotlib.axis.XTick at 0x7f400c66c908>,
#   <matplotlib.axis.XTick at 0x7f400c6d78d0>,
#   <matplotlib.axis.XTick at 0x7f400c67a0f0>,
#   <matplotlib.axis.XTick at 0x7f400c67a5f8>,
#   <matplotlib.axis.XTick at 0x7f400c67ab70>,
#   <matplotlib.axis.XTick at 0x7f400c682160>,
#   <matplotlib.axis.XTick at 0x7f400c6826a0>,
#   <matplotlib.axis.XTick at 0x7f400c682c18>,
#   <matplotlib.axis.XTick at 0x7f400c6891d0>,
#   <matplotlib.axis.XTick at 0x7f400c682518>,
#   <matplotlib.axis.XTick at 0x7f400c67a550>,
#   <matplotlib.axis.XTick at 0x7f400c689518>,
#   <matplotlib.axis.XTick at 0x7f400c689c50>,
#   <matplotlib.axis.XTick at 0x7f400c68f208>,
#   <matplotlib.axis.XTick at 0x7f400c68f780>,
#   <matplotlib.axis.XTick at 0x7f400c68fcf8>,
#   <matplotlib.axis.XTick at 0x7f400c6972b0>,
#   <matplotlib.axis.XTick at 0x7f400c697828>,
#   <matplotlib.axis.XTick at 0x7f400c697da0>,
#   <matplotlib.axis.XTick at 0x7f400c697908>,
#   <matplotlib.axis.XTick at 0x7f400c689d30>,
#   <matplotlib.axis.XTick at 0x7f400c69f278>,
#   <matplotlib.axis.XTick at 0x7f400c69f7f0>,
#   <matplotlib.axis.XTick at 0x7f400c69fd68>,
#   <matplotlib.axis.XTick at 0x7f400c6a5320>,
#   <matplotlib.axis.XTick at 0x7f400c6a5898>,
#   <matplotlib.axis.XTick at 0x7f400c6a5e10>,
#   <matplotlib.axis.XTick at 0x7f400c62c3c8>,
#   <matplotlib.axis.XTick at 0x7f400c6a53c8>,
#   <matplotlib.axis.XTick at 0x7f400c69f5f8>,
#   <matplotlib.axis.XTick at 0x7f400c62c710>,
#   <matplotlib.axis.XTick at 0x7f400c62ce48>,
#   <matplotlib.axis.XTick at 0x7f400c634400>,
#   <matplotlib.axis.XTick at 0x7f400c634978>,
#   <matplotlib.axis.XTick at 0x7f400c634ef0>,
#   <matplotlib.axis.XTick at 0x7f400c63b4a8>,
#   <matplotlib.axis.XTick at 0x7f400c63ba20>,
#   <matplotlib.axis.XTick at 0x7f400c63be80>,
#   <matplotlib.axis.XTick at 0x7f400c63b9e8>,
#   ...],
#  <a list of 35952 Text xticklabel objects>)
