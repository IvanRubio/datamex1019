# %% [markdown]
# # Before you start :
#    - These exercises are related to the Subsetting and Descriptive Stats lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# import libraries here
import pandas as pd
import numpy as np

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### In this challenge we will use the `Temp_States.csv` file.
#
# #### First import it into a data frame called `temp`.

# %%
# your answer here
temp=pd.read_csv('Temp_States.csv')
temp.head()
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444

# %% [markdown]
# #### Print `temp`

# %%
temp
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the Temp dataframe. What type of data do we have? Comment your result.

# %%
# your answer here
#Ciudades y sus temperaturas
temp.columns
# Out:
# Index(['City', 'State', 'Temperature'], dtype='object')

# %% [markdown]
# #### Select the rows where state is New York

# %%
# your answer here
ny=temp.loc[temp.State == 'New York']
ny
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average of the temperature of cities in New York?

# %%
# your answer here
ny.mean()
# Out:
# Temperature    10.740741
# dtype: float64

# %% [markdown]
# #### We want to know cities and states with Temperature above 15 degress Celcius

# %%
# your answer here
temp.loc[(temp.Temperature > 15)]
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degress Celcius

# %%
# your answer here
temp.loc[(temp.Temperature > 15), ['City','Temperature']]
# Out:
#        City  Temperature
# 0       NYC    19.444444
# 3  Hartford    17.222222
# 5    Treton    22.222222
# 6    Newark    20.000000

# %% [markdown]
# #### We want to know which cities have a temperature above 15 degrees Celcius and below 20 degrees Celcius
#
# *Hint: First write the condition then select the rows.*

# %%
# your answer here
temp.loc[(temp.Temperature>15)&(temp.Temperature<20),['City','Temperature']]
# Out:
#        City  Temperature
# 0       NYC    19.444444
# 3  Hartford    17.222222

# %% [markdown]
# #### Find the mean and the standard deviation of the temperature of each state.
#
# *Hint: Use functions from Data Manipulation lesson*

# %%
#Así no me salió...
#medias=temp.loc[(temp.State == 'Connecticut'),(temp.State == 'New Jersey')]
#print(medias.mean())

#Pero así sí, aunque creo que no es óptimo...
njer=temp.loc[temp.State == 'New Jersey']
con=temp.loc[temp.State == 'Connecticut']
print(con.mean())
print(njer.mean())
print(ny.mean())
# Out:
# Temperature    15.833333
# dtype: float64
# Temperature    21.111111
# dtype: float64
# Temperature    10.740741
# dtype: float64

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Load the `employee.csv` file into a DataFrame. Call the dataframe `employee`

# %%
# your answer here
employee=pd.read_csv('Employee.csv')
employee.head()
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55

# %% [markdown]
# #### Explore the data types of the Temp dataframe. Comment your results

# %%
# your answer here
employee.dtypes

#las ciudades y estado deberían ser string
# Out:
# Name          object
# Department    object
# Education     object
# Gender        object
# Title         object
# Years          int64
# Salary         int64
# dtype: object

# %% [markdown]
# #### Show visually the frequency distribution (histogram) of the employee dataset. In few words describe these histograms?

# %%
# your answer here
import matplotlib.pyplot as plt

# %% [markdown]
# #### What's the average salary in this company?

# %%
# your answer here
employee['Salary'].mean()
# Out:
# 48.888888888888886

# %% [markdown]
# #### What's the highest salary?

# %%
# your answer here
employee['Salary'].max()
# Out:
# 70

# %% [markdown]
# #### What's the lowest salary?

# %%
# your answer here
employee['Salary'].min()
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# your answer here
employee[['Salary', 'Name']].min()
# Out:
# Salary     30
# Name      Ana
# dtype: object

# %% [markdown]
# #### Could you give all the information about an employee called David?

# %%
# your answer here
employee.loc[employee.Name=='David']
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give only David's salary?

# %%
# your answer here
employee.loc[(employee.Name=='David'),['Salary']]
# Out:
#    Salary
# 2      30

# %% [markdown]
# #### Print all the rows where job title is associate

# %%
# your answer here
employee.loc[employee.Title=='associate']
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe
#
# ##### Tip : There are 2 ways to do it. Do it both ways

# %%
# your answer here- 1 method
employee.head(3)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
# your answer here- 2nd method

# %% [markdown]
# #### Find the employees who's title is associate and the salary above 55?

# %%
# your answer here
employee.loc[(employee.Title=='associate')&(employee.Salary>55),['Title','Salary']]
# Out:
#        Title  Salary
# 7  associate      60

# %% [markdown]
# #### Group the employees based on their number of years of employment. What are the average salaries in each group?

# %%
# your answer here
employee.groupby('Years').size()
# Out:
# Years
# 1    1
# 2    3
# 3    1
# 4    1
# 7    1
# 8    2
# dtype: int64

# %% [markdown]
# ####  What is the average Salary per title?

# %%
# your answer here
employee['Salary'].mean()
# Out:
# 48.888888888888886

# %% [markdown]
# #### Show a visual summary of the data using boxplot. What Are the First and Third Quartiles? Comment your results.
# ##### * Hint : Quantiles vs Quartiles*
# ##### - `In Probability and Statistics, quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities. When division is into four parts the values of the variate corresponding to 25%, 50% and 75% of the total distribution are called quartiles.`

# %%
# draw boxplot here
# %matplotlib inline
import matplotlib.pyplot as plt
plt.figure(figsize=(15,10))
employee.boxplot();

# %%
# print first quartile here
#print("First quartile: ", np.quantile(employee, .25))
plt.figure(figsize=(15,10))
employee.boxplot(np.quantile(employee, 0.25));
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-41561dc30f0f> in <module>
#       2 #print("First quartile: ", np.quantile(employee, .25))
#       3 plt.figure(figsize=(15,10))
# ----> 4 employee.boxplot(np.quantile(employee, 0.25));
#
# <__array_function__ internals> in quantile(*args, **kwargs)
#
# /home/ivan/snap/jupyter/common/lib/python3.7/site-packages/numpy/lib/function_base.py in quantile(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3823         raise ValueError("Quantiles must be in the range [0, 1]")
#    3824     return _quantile_unchecked(
# -> 3825         a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3826
#    3827
#
# /home/ivan/snap/jupyter/common/lib/python3.7/site-packages/numpy/lib/function_base.py in _quantile_unchecked(a, q, axis, out, overwrite_input, interpolation, keepdims)
# ...

# %%
# print third quartile here
plt.figure(figsize=(15,10))
employee.boxplot(np.quantile(employee, 0.75));
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-2bc91a798ce0> in <module>
#       1 # print third quartile here
#       2 plt.figure(figsize=(15,10))
# ----> 3 employee.boxplot(np.quantile(employee, 0.75));
#
# <__array_function__ internals> in quantile(*args, **kwargs)
#
# /home/ivan/snap/jupyter/common/lib/python3.7/site-packages/numpy/lib/function_base.py in quantile(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3823         raise ValueError("Quantiles must be in the range [0, 1]")
#    3824     return _quantile_unchecked(
# -> 3825         a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3826
#    3827
#
# /home/ivan/snap/jupyter/common/lib/python3.7/site-packages/numpy/lib/function_base.py in _quantile_unchecked(a, q, axis, out, overwrite_input, interpolation, keepdims)
# ...

# %% [markdown]
# #### Is the mean salary per gender different?

# %%
# your answer here
employee.loc[(employee.Gender=='F'),['Gender']]
# Out:
#   Gender
# 1      F
# 3      F
# 5      F
# 8      F

# %% [markdown]
# #### Find the minimum, mean and the maximum of all numeric columns for each Department.
#
# ##### Hint: Use functions from Data Manipulation lesson

# %%
# your answer here
print(employee[['Years','Salary']].mean())

print(employee[['Years','Salary']].min())

print(employee[['Years','Salary']].max())
# Out:
# Years      4.111111
# Salary    48.888889
# dtype: float64
# Years      1
# Salary    30
# dtype: int64
# Years      8
# Salary    70
# dtype: int64

# %% [markdown]
# ### Bonus Question
#
# #### For each department, compute the difference between the maximal salary and the minimal salary.
#
# ##### * Hint: try using `agg` or `apply` and `lambda`*

# %%
# your answer here

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the Orders.csv dataset. Name your dataset orders

# %%
# your answer here
orders=pd.read_csv("Orders.zip")
orders
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0                0     536365    85123A  2010     12    3     8
# 1                1     536365     71053  2010     12    3     8
# 2                2     536365    84406B  2010     12    3     8
# 3                3     536365    84029G  2010     12    3     8
# 4                4     536365    84029E  2010     12    3     8
# ...            ...        ...       ...   ...    ...  ...   ...
# 397919      541904     581587     22613  2011     12    5    12
# 397920      541905     581587     22899  2011     12    5    12
# 397921      541906     581587     23254  2011     12    5    12
# 397922      541907     581587     23255  2011     12    5    12
# 397923      541908     581587     22138  2011     12    5    12
#
#                                 Description  Quantity          InvoiceDate  \
# 0        white hanging heart t-light holder         6  2010-12-01 08:26:00
# ...

# %% [markdown]
# #### Explore your dataset by looking at the data types and the summary statistics. Comment your results

# %%
# your answer here
orders.dtypes
# Out:
# Unnamed: 0        int64
# InvoiceNo         int64
# StockCode        object
# year              int64
# month             int64
# day               int64
# hour              int64
# Description      object
# Quantity          int64
# InvoiceDate      object
# UnitPrice       float64
# CustomerID        int64
# Country          object
# amount_spent    float64
# dtype: object

# %%
# your answer here

#El país es un objeto y creo que debería ser un string
#Hay una columna "unamed" que creo que no sirve para nada

# %% [markdown]
# ####  What is the average Purchase Price?

# %%
# your answer here
orders.UnitPrice.mean()
# Out:
# 3.1161744805540756

# %% [markdown]
# #### What were the highest and lowest purchase prices?

# %%
# your answer here
#df[df.brainwt==df.brainwt.max()].animal
print(orders.UnitPrice.max())
print(orders.UnitPrice.min())
# Out:
# 8142.75
# 0.0

# %%
# your answer here

# %% [markdown]
# #### Select all the customers we have in Spain

# %%
# your answer here
orders.loc[(orders.Country=='Spain'),['CustomerID','Country']]
# Out:
#         CustomerID Country
# 4250         12557   Spain
# 4251         12557   Spain
# 4252         12557   Spain
# 4253         12557   Spain
# 4254         12557   Spain
# ...            ...     ...
# 394733       17097   Spain
# 394734       17097   Spain
# 394735       17097   Spain
# 394736       17097   Spain
# 394737       17097   Spain
#
# [2485 rows x 2 columns]

# %% [markdown]
# #### How many customers do we have in Spain?
# ##### Hint : Use value_counts()

# %%
# your answer here
orders['Quantity'].value_counts()
# Out:
# 1       73314
# 12      60033
# 2       58003
# 6       37688
# 4       32183
#         ...
# 824         1
# 101         1
# 1788        1
# 59          1
# 1404        1
# Name: Quantity, Length: 302, dtype: int64

# %% [markdown]
# #### Select all the customers who have bought more than 50 items ?

# %%
# your answer here
orders['CustomerID'].value_counts()>50
# Out:
# 17841     True
# 14911     True
# 14096     True
# 12748     True
# 14606     True
#          ...
# 17331    False
# 16093    False
# 13703    False
# 13307    False
# 12346    False
# Name: CustomerID, Length: 4339, dtype: bool

# %% [markdown]
# #### Select orders from Spain that are above 50 items

# %%
# your answer here
orders.loc[(orders['Country'].value_counts()>50)&(orders.Country=='Spain')]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, InvoiceNo, StockCode, year, month, day, hour, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country, amount_spent]
# Index: []

# %% [markdown]
# #### Select all free orders

# %%
# your answer here
orders.loc[orders.UnitPrice==0]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 6914          9302     537197     22841  2010     12    7    14
# 22539        33576     539263     22580  2010     12    4    14
# 25379        40089     539722     22423  2010     12    2    13
# 29080        47068     540372     22090  2011      1    4    16
# 29082        47070     540372     22553  2011      1    4    16
# 34494        56674     541109     22168  2011      1    4    15
# 53788        86789     543599    84535B  2011      2    4    13
# 85671       130188     547417     22062  2011      3    3    10
# 92875       139453     548318     22055  2011      3    3    12
# 97430       145208     548871     22162  2011      4    1    14
# 107192      157042     550188     22636  2011      4    4    18
# 128641      187613     553000     47566  2011      5    4    15
# 137127      198383     554037     22619  2011      5    5    14
# 194648      279324     561284     22167  2011      7    2    12
# ...

# %% [markdown]
# #### Select all orders that are 'lunch bag'
# #### Hint: Use string functions

# %%
# your answer here
orders.loc[orders.Description=='lunch bag']
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, InvoiceNo, StockCode, year, month, day, hour, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country, amount_spent]
# Index: []

# %% [markdown]
# #### Select all orders that are made in 2011 and are 'lunch bag'

# %%
# your answer here
orders.loc[(orders.Description=="lunch bag")&(orders.year==2011)]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, InvoiceNo, StockCode, year, month, day, hour, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country, amount_spent]
# Index: []

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your answer here

# %% [markdown]
# #### Select all orders made in the month of August

# %%
# your answer here
orders.loc[orders.month==8]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 199475      285421     561904     22075  2011      8    1     8
# 199476      285422     561904    85049E  2011      8    1     8
# 199477      285423     561905     21385  2011      8    1     9
# 199478      285424     561905    84970L  2011      8    1     9
# 199479      285425     561905    84970S  2011      8    1     9
# ...            ...        ...       ...   ...    ...  ...   ...
# 226483      320688     565067     22644  2011      8    3    17
# 226484      320689     565067     22645  2011      8    3    17
# 226485      320690     565067     22637  2011      8    3    17
# 226486      320691     565067     22646  2011      8    3    17
# 226487      320692     565067     22741  2011      8    3    17
#
#                                 Description  Quantity          InvoiceDate  \
# 199475         6 ribbons elegant christmas         96  2011-08-01 08:30:00
# ...

# %% [markdown]
# #### Select how many orders are made by countries in the month of August
# ##### Hint: Use value_counts()

# %%
# your answer here
orders.loc[orders['Country'].value_counts()]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 354345      480824     577319     23085  2011     11    5    13
# 9042         12657     537391     82580  2010     12    1    13
# 8342         11949     537351     22219  2010     12    1    12
# 7238          9628     537208    90082B  2010     12    7    15
# 2485          3654     536638     21383  2010     12    4    11
# 2363          3532     536635     22114  2010     12    4    11
# 2031          3198     536609     21068  2010     12    4     9
# 1842          2410     536590     22114  2010     12    3    16
# 1462          2021     536551     22629  2010     12    3    14
# 1185          1196     536530     22120  2010     12    3    13
# 1072          1083     536524     21111  2010     12    3    12
# 758            768     536460     84992  2010     12    3    12
# 748            758     536446     21651  2010     12    3    12
# 685            695     536420     22113  2010     12    3    12
# ...

# %% [markdown]
# #### What's the  average amount of money spent by country

# %%
# your answer here
orders['amount_spent'].mean()

#Nota para Oscar y Vania: aquí no supe cómo hacer el equivalente de lo que sería "GROUP BY Country" en SQL
# Out:
# 22.394748504739596

# %% [markdown]
# #### What's the most expensive item?

# %%
# your answer here
orders['UnitPrice'].max()
#duda... aquí cómo le hago para desplegar las demás columnas?
# Out:
# 8142.75

# %% [markdown]
# #### What was the average amount spent per year ?

# %%
# your answer here
orders['amount_spent'].mean()
# Out:
# 22.394748504739596
