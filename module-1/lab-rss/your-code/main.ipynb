# %% [markdown]
# # Working with RSS Feeds Lab
#
# Complete the following set of exercises to solidify your knowledge of parsing RSS feeds and extracting information from them.

# %%
import feedparser

# %% [markdown]
# ### 1. Use feedparser to parse the following RSS feed URL.

# %%
url = 'http://feeds.feedburner.com/oreilly/radar/atom'

# %%
rss = feedparser.parse('http://feeds.feedburner.com/oreilly/radar/atom')
rss
# Out:
# {'feed': {'title': 'Radar',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'Radar'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'https://www.oreilly.com/radar'},
#    {'rel': 'self',
#     'type': 'application/rss+xml',
#     'href': 'http://feeds.feedburner.com/oreilly/radar/atom'},
#    {'rel': 'hub',
#     'href': 'http://pubsubhubbub.appspot.com/',
#     'type': 'text/html'}],
#   'link': 'https://www.oreilly.com/radar',
#   'subtitle': 'Now, next, and beyond: Tracking need-to-know trends at the intersection of business and technology',
#   'subtitle_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'Now, next, and beyond: Tracking need-to-know trends at the intersection of business and technology'},
#   'updated': 'Wed, 13 Nov 2019 12:06:03 +0000',
#   'updated_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=13, tm_hour=12, tm_min=6, tm_sec=3, tm_wday=2, tm_yday=317, tm_isdst=0),
#   'language': 'en-US',
#   'sy_updateperiod': 'hourly',
#   'sy_updatefrequency': '1',
#   'generator_detail': {'name': 'https://wordpress.org/?v=5.2.4'},
#   'generator': 'https://wordpress.org/?v=5.2.4',
#   'feedburner_info': {'uri': 'oreilly/radar/atom'},
#   'geo_lat': '38.393314',
#   'geo_long': '-122.836667',
#   'feedburner_emailserviceid': 'oreilly/radar/atom',
#   'feedburner_feedburnerhostname': 'https://feedburner.google.com'},
#  'entries': [{'title': 'Four short links: 13 November 2019',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Four short links: 13 November 2019'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/ID1RcQfYgOk/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/ID1RcQfYgOk/',
#    'comments': 'https://www.oreilly.com/radar/four-short-links-13-november-2019/#respond',
#    'published': 'Wed, 13 Nov 2019 05:01:22 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=13, tm_hour=5, tm_min=1, tm_sec=22, tm_wday=2, tm_yday=317, tm_isdst=0),
#    'authors': [{'name': 'Nat Torkington'}],
#    'author': 'Nat Torkington',
#    'author_detail': {'name': 'Nat Torkington'},
#    'tags': [{'term': 'Four Short Links', 'scheme': None, 'label': None},
#     {'term': 'Signals', 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=10848',
#    'guidislink': False,
#    'summary': 'Learning to Smell: Using Deep Learning to Predict the Olfactory Properties of Molecules (Google) &#8212; a readable walk through of how they model and make sense of smells. Diversified Sampling: Mining Large Datasets for Special Cases &#8212; TL;DR: the objective is to build a small sample of the data in which special cases are likely [&#8230;]',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Learning to Smell: Using Deep Learning to Predict the Olfactory Properties of Molecules (Google) &#8212; a readable walk through of how they model and make sense of smells. Diversified Sampling: Mining Large Datasets for Special Cases &#8212; TL;DR: the objective is to build a small sample of the data in which special cases are likely [&#8230;]'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<ol><li><a href="https://ai.googleblog.com/2019/10/learning-to-smell-using-deep-learning.html">Learning to Smell: Using Deep Learning to Predict the Olfactory Properties of Molecules</a> (Google) &#8212; a readable walk through of how they model and make sense of smells.</li><li><a href="https://vvvvalvalval.github.io/posts/2019-09-13-diversified-sampling-mining-large-datasets-for-special-cases.html">Diversified Sampling: Mining Large Datasets for Special Cases</a> &#8212; <em>TL;DR: the objective is to build a small sample of the data in which special cases are likely to be represented. The strategy is to have each data item emit a list of &#8220;features,&#8221; and to boost the probability of selecting rare features. A shallow understanding of the data is often enough to design an effective features extraction.</em></li><li><a href="https://github.com/datamllab/rlcard">RLCard</a> &#8212; open source reinforcement learning toolkit for card games. <a href="https://arxiv.org/pdf/1910.04376.pdf">Paper</a>. (via <a href="https://medium.com/syncedreview/texas-a-m-and-simon-fraser-universities-open-source-rl-toolkit-for-card-games-858e22195f36">SyncedReview</a>)</li><li><a href="https://github.com/xo/usql">usql</a> &#8212; <em>Universal command-line interface for SQL databases</em>.</li></ol>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/ID1RcQfYgOk" height="1" width="1" alt=""/>'}],
#    'wfw_commentrss': 'https://www.oreilly.com/radar/four-short-links-13-november-2019/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/four-short-links-13-november-2019/'},
#   {'title': 'O’Reilly serverless survey 2019: Concerns, what works, and what to expect',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'O’Reilly serverless survey 2019: Concerns, what works, and what to expect'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/Tpz60LEjmU4/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/Tpz60LEjmU4/',
#    'comments': 'https://www.oreilly.com/radar/oreilly-serverless-survey-2019-concerns-what-works-and-what-to-expect/#respond',
#    'published': 'Tue, 12 Nov 2019 12:00:41 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=12, tm_hour=12, tm_min=0, tm_sec=41, tm_wday=1, tm_yday=316, tm_isdst=0),
#    'authors': [{'name': 'Roger Magoulas and Chris Guzikowski'}],
#    'author': 'Roger Magoulas and Chris Guzikowski',
#    'author_detail': {'name': 'Roger Magoulas and Chris Guzikowski'},
#    'tags': [{'term': 'Next Architecture', 'scheme': None, 'label': None},
#     {'term': 'Research', 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=9819',
#    'guidislink': False,
#    'summary': 'For the inaugural O’Reilly survey on serverless architecture adoption, we were pleasantly surprised at the high level of response: more than 1,500 respondents from a wide range of locations, companies, and industries participated. The high response rate tells us that serverless is garnering significant mindshare in the community.1 Key findings from the survey include: 40% [&#8230;]',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'For the inaugural O’Reilly survey on serverless architecture adoption, we were pleasantly surprised at the high level of response: more than 1,500 respondents from a wide range of locations, companies, and industries participated. The high response rate tells us that serverless is garnering significant mindshare in the community.1 Key findings from the survey include: 40% [&#8230;]'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p><p id="F1">For the inaugural O’Reilly survey on serverless architecture adoption, we were pleasantly surprised at the high level of response: more than 1,500 respondents from a wide range of locations, companies, and industries participated. The high response rate tells us that serverless is garnering significant mindshare in the community.<a href="#_ftn1"><sup>1</sup></a></p>\n\n\n\n<p>Key findings from the survey include:</p>\n\n\n\n<ul><li>40% of respondents work at organizations that have adopted serverless architecture in some form or another. Reduced operational costs and automatic scaling are the top serverless benefits cited by this group.</li><li>Of the 60% of respondents whose companies haven&#8217;t adopted serverless, the leading concerns about the paradigm are security and fear of the unknown.</li><li>About 50% of respondents who adopted serverless three-plus years ago consider their implementations successful or extremely successful, a contrast to the 35% of those adopting serverless a year or less ago experiencing a successful or extremely successful implementation—a gap that suggests serverless experience pays off.</li><li>Respondents who have implemented serverless made custom tooling the top tool choice—implying that vendors’ tools may not fully address what organizations need to deploy and manage a serverless infrastructure.</li></ul>\n\n\n\n<p>In our analysis, we assigned experience levels to our respondents for some of the survey questions. New respondents work at organizations that have tried serverless for less than one year. Early respondents’ organizations have employed serverless for one to three years. Sophisticated respondents work at organizations that have been using serverless for more than three years.</p>\n\n\n\n<h2>What respondents do and where they work</h2>\n\n\n\n<figure class="wp-block-image"><img src="https://www.oreilly.com/radar/wp-content/uploads/sites/3/2019/10/Figure1-e1570028458892-1048x647.png" alt="Serverless Survey figure 1" class="wp-image-9803" srcset="https://www.oreilly.com/radar/wp-content/uploads/sites/3/2019/10/Figure1-e1570028458892-1048x647.png 1048w, https://www.oreilly.com/radar/wp-content/uploads/sites/3/2019/10/Figure1-e1570028458892-300x185.png 300w, https://www.oreilly.com/radar/wp-content/uploads/sites/3/2019/10/Figure1-e1570028458892-768x474.png 768w, https://www.oreilly.com/radar/wp-content/uploads/sites/3/2019/10/Figure1-e1570028458892.png 1400w" sizes="(max-width: 1048px) 100vw, 1048px" /><figcaption>Figure 1. Roles of survey respondents.</figcaption></figure>\n\n\n\n<p>Looking at the role distribution among respondents, we see that those exploring and using the serverless paradigm are not confined to a single role. We suspect this points to a general drift toward software teams taking more responsibility for infrastructure, and increasingly, enabled by serverless options.</p>\n\n\n\n<figure class="wp-block-image"><img src="https://www.oreilly.com/radar/wp-content/uploads/sites/3/2019/10/Figure2-1048x711.png" alt="Serverless Survey figure 2" class="wp-image-9804" srcset="https://www.oreilly.com/radar/wp-content/uploads/sites/3/2019/10/Figure2-1048x711.png 1048w, https://www.oreilly.com/radar/wp-content/uploads/sites/3/2019/10/Figure2-300x204.png 300w, https://www.oreilly.com/radar/wp-content/uploads/sites/3/2019/10/Figure2-768x521.png 768w, https://www.oreilly.com/radar/wp-content/uploads/sites/3/2019/10/Figure2.png 1400w" sizes="(max-width: 1048px) 100vw, 1048px" /><figcaption>Figure 2. Industries of survey respondents.</figcaption></figure>\n\n\n\n<p>More than a fifth of the respondents work in the software industry—skewing results toward the concerns of software companies, and helping explain the preponderance of those with software engineering roles.</p>\n\n\n\n<p>Finance and banking, the vertical with the second highest share of respondents, may include the growing number of fintech startups that, with no burden of legacy infrastructure, ...
#    'wfw_commentrss': 'https://www.oreilly.com/radar/oreilly-serverless-survey-2019-concerns-what-works-and-what-to-expect/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/oreilly-serverless-survey-2019-concerns-what-works-and-what-to-expect/'},
#   {'title': 'Improving the military UX',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Improving the military UX'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/XeRPWuPwIDk/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/XeRPWuPwIDk/',
#    'comments': 'https://www.oreilly.com/radar/improving-the-military-ux/#respond',
#    'published': 'Tue, 12 Nov 2019 05:10:49 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=12, tm_hour=5, tm_min=10, tm_sec=49, tm_wday=1, tm_yday=316, tm_isdst=0),
#    'authors': [{'name': 'Jenn Webb'}],
#    'author': 'Jenn Webb',
#    'author_detail': {'name': 'Jenn Webb'},
#    'tags': [{'term': 'Innovation & Disruption', 'scheme': None, 'label': None},
#     {'term': 'Deep Dive', 'scheme': None, 'label': None},
#     {'term': "Foo Camp '19", 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=9575',
#    'guidislink': False,
#    'summary': 'In this interview from O&#8217;Reilly Foo Camp 2019, Noah Firth, director at the Air Force Digital Service, talks about the challenges of making the US military more user-friendly, the unique recruiting parameters for team members, and the success metrics that guide his team. Highlights from this interview include: Firth&#8217;s team&#8217;s main focus is on how [&#8230;]',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'In this interview from O&#8217;Reilly Foo Camp 2019, Noah Firth, director at the Air Force Digital Service, talks about the challenges of making the US military more user-friendly, the unique recruiting parameters for team members, and the success metrics that guide his team. Highlights from this interview include: Firth&#8217;s team&#8217;s main focus is on how [&#8230;]'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p>In this interview from O&#8217;Reilly Foo Camp 2019, Noah Firth, director at the Air Force Digital Service, talks about the challenges of making the US military more user-friendly, the unique recruiting parameters for team members, and the success metrics that guide his team.</p>\n\n<p>Highlights from this interview include:</p>\n\n<p>Firth&#8217;s team&#8217;s main focus is on how technology can be used to improve the lives of US military service members and their families. He describes the significance of a large project they&#8217;re wrapping up, move.mil. &#8220;Military service members have to move every two to four years, and the system that was enabling those moves was generally hostile toward the user experience. We&#8217;re working to use modern technologies to implement a new-and-improved system to schedule the moves to allow service members&#8217; spouses and family members to be active participants in figuring out how they&#8217;re going to uproot their lives and move across the country or around the world.&#8221; (<a href="#t=2">00:02</a>)</p>\n\n<p>Recruiting is a challenge for any organization, but it&#8217;s particularly quirky for teams working with government organizations, Firth explains. He looks for folks who are not only at the top of their fields, but for those able to maneuver around the frustrations of slow-moving bureaucracy. &#8220;We have what we call core competencies&mdash;questions we ask and things we look for to determine whether or not someone&#8217;s going to be a good fit in our organization. &#8230; Some of those things that we call &#8217;emotional quotient&#8217; are as important if not more so than some of the technical quotient things we&#8217;re looking for. &#8230; We have to go through an enormous amount of validation of a person&#8217;s prior experiences, but then also a validation of them as a human. It gives us the ability to do the whole person concept, to make sure that, as we have a small team and we have to maintain a small team, we can work to make that small team work well together.&#8221; (<a href="#t=57">00:57</a>)\n\n<p>One might think it wouldn&#8217;t be difficult, Firth notes, but one of the main success metrics he uses is whether or not they can convince others that technology can make their lives better. Also in Firth&#8217;s case, the military leadership he deals with turns over every two to four years; all around, he&#8217;s on a &#8220;constant education campaign.&#8221; Firth outlines how he measures overall success: &#8220;Have we made the user&#8217;s life better? Have we used technology to do so in a way that appreciates (1) the capability of the technology, but also (2), the capability of the people who are implementing that technology and will have to do so long term? Then (3), have we walked away leaving behind us a legacy of creating that understanding of what technology could be used for?&#8221; (<a href="#t=198">03:18</a>)</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/XeRPWuPwIDk" height="1" width="1" alt=""/>'}],
#    'wfw_commentrss': 'https://www.oreilly.com/radar/improving-the-military-ux/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/improving-the-military-ux/'},
#   {'title': 'Four short links: 12 November 2019',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Four short links: 12 November 2019'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/EfPiWqaP7yM/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/EfPiWqaP7yM/',
#    'comments': 'https://www.oreilly.com/radar/four-short-links-12-november-2019/#respond',
#    'published': 'Tue, 12 Nov 2019 05:01:10 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=12, tm_hour=5, tm_min=1, tm_sec=10, tm_wday=1, tm_yday=316, tm_isdst=0),
#    'authors': [{'name': 'Nat Torkington'}],
#    'author': 'Nat Torkington',
#    'author_detail': {'name': 'Nat Torkington'},
#    'tags': [{'term': 'Four Short Links', 'scheme': None, 'label': None},
#     {'term': 'Signals', 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=10835',
#    'guidislink': False,
#    'summary': 'Uyghur Detecting &#8220;Smart&#8221; Camera &#8212; this should start hard conversations in your workplace about what you build. (via BoingBoing) Deep Tech Trends 2019 &#8212; a lot of companies doing a lot of things. So many utility Daleks that will&#8230;clean your floors, clean your toilet, run your landfill, hold your drill&#8230; SandDance &#8212; By using easy-to-understand [&#8230;]',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Uyghur Detecting &#8220;Smart&#8221; Camera &#8212; this should start hard conversations in your workplace about what you build. (via BoingBoing) Deep Tech Trends 2019 &#8212; a lot of companies doing a lot of things. So many utility Daleks that will&#8230;clean your floors, clean your toilet, run your landfill, hold your drill&#8230; SandDance &#8212; By using easy-to-understand [&#8230;]'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<ol><li><a href="https://ipvm.com/reports/hikvision-uyghur">Uyghur Detecting &#8220;Smart&#8221; Camera</a> &#8212; this should start hard conversations in your workplace about what you build. (via <a href="https://boingboing.net/2019/11/11/ethnicity-detection-camera.html">BoingBoing</a>)</li><li><a href="https://www.slideshare.net/SOSv/deep-tech-trends-2019">Deep Tech Trends 2019</a> &#8212; a lot of companies doing a lot of things. So many utility Daleks that will&#8230;clean your floors, clean your toilet, run your landfill, hold your drill&#8230;</li><li><a href="https://sanddance.js.org/">SandDance</a> &#8212; <em>By using easy-to-understand views, SandDance helps you find insights about your data, which in turn help you tell stories supported by data, build cases based on evidence, test hypotheses, dig deeper into surface explanations, support decisions for purchases, or relate data into a wider, real-world context. SandDance uses unit visualizations, which apply a one-to-one mapping between rows in your database and marks on the screen. Smooth animated transitions between views help you to maintain context as you interact with your data.</em></li><li><a href="https://developers.google.com/machine-learning/guides/rules-of-ml/">Rules of Machine Learning</a> (Google) &#8212; <em>A simple heuristic can get your product out the door. A complex heuristic is unmaintainable. Once you have data and a basic idea of what you are trying to accomplish, move on to machine learning. As in most software engineering tasks, you will want to be constantly updating your approach, whether it is a heuristic or a machine\xad-learned model, and you will find that the machine\xad-learned model is easier to update and maintain.</em></li></ol>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/EfPiWqaP7yM" height="1" width="1" alt=""/>'}],
#    'wfw_commentrss': 'https://www.oreilly.com/radar/four-short-links-12-november-2019/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/four-short-links-12-november-2019/'},
#   {'title': 'Four short links: 11 November 2019',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Four short links: 11 November 2019'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/njtsEULYt_g/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/njtsEULYt_g/',
#    'comments': 'https://www.oreilly.com/radar/four-short-links-11-november-2019/#respond',
#    'published': 'Mon, 11 Nov 2019 05:01:56 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=11, tm_hour=5, tm_min=1, tm_sec=56, tm_wday=0, tm_yday=315, tm_isdst=0),
#    'authors': [{'name': 'Nat Torkington'}],
#    'author': 'Nat Torkington',
#    'author_detail': {'name': 'Nat Torkington'},
#    'tags': [{'term': 'Four Short Links', 'scheme': None, 'label': None},
#     {'term': 'Signals', 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=10811',
#    'guidislink': False,
#    'summary': 'WebAssembly.sh an open source terminal that uses the WebAssembly Package Manager (WAPM) and local files to run server-side Wasm / WASI modules in a shell-like interface. (via Mikeal Rogers) Russia’s Suspected Internet Cable Spy Ship Appears Off Americas (Forbes) &#8212; assume your network is compromised, as you should always have done. Before enlightenment: encryption. After [&#8230;]',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'WebAssembly.sh an open source terminal that uses the WebAssembly Package Manager (WAPM) and local files to run server-side Wasm / WASI modules in a shell-like interface. (via Mikeal Rogers) Russia’s Suspected Internet Cable Spy Ship Appears Off Americas (Forbes) &#8212; assume your network is compromised, as you should always have done. Before enlightenment: encryption. After [&#8230;]'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<ol><li><a href="https://webassembly.sh/">WebAssembly.sh</a>   <em>an open source terminal that uses the WebAssembly Package Manager (WAPM) and local files to run server-side Wasm / WASI modules in a shell-like interface.</em> (via <a href="https://twitter.com/mikeal/status/1192520347440099335">Mikeal Rogers</a>)</li><li><a href="https://www.forbes.com/sites/hisutton/2019/11/10/russias-suspected-internet-cable-spy-ship-appears-off-americas/#60ae8c6b42d5">Russia’s Suspected Internet Cable Spy Ship Appears Off Americas</a> (Forbes) &#8212; assume your network is compromised, as you should always have done. Before enlightenment: encryption. After enlightenment: encryption.</li><li><a href="https://yannherklotz.com/docs/verismith/verismith_paper.pdf">Finding and Understanding Bugs in FPGA Synthesis Tools</a> &#8212; <em>Every synthesis tool was found to introduce discrepancies between the netlist and the design, and all tools except XST crashed when given valid input. Vivado was found to missynthesise 4% of random testcases that it was given.</em></li><li><a href="https://www.nature.com/articles/s41599-019-0279-9">Fake News Game Confers Psychological Resistance Against Online Misinformation</a> (Nature) &#8212; <em>In the game, players take on the role of a fake news producer and learn to master six documented techniques commonly used in the production of misinformation: polarization, invoking emotions, spreading conspiracy theories, trolling people online, deflecting blame, and impersonating fake accounts. The game draws on an inoculation metaphor, where preemptively exposing, warning, and familiarizing people with the strategies used in the production of fake news helps confer cognitive immunity when exposed to real misinformation. We conducted a large-scale evaluation of the game with N = 15,000 participants in a pre-post gameplay design. We provide initial evidence that people’s ability to spot and resist misinformation improves after gameplay, irrespective of education, age, political ideology, and cognitive style.</em></li></ol>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/njtsEULYt_g" height="1" width="1" alt=""/>'}],
#    'wfw_commentrss': 'https://www.oreilly.com/radar/four-short-links-11-november-2019/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/four-short-links-11-november-2019/'},
#   {'title': 'Bitcoin and the disruption of monetary oppression',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Bitcoin and the disruption of monetary oppression'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/ENi7moVeFTY/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/ENi7moVeFTY/',
#    'comments': 'https://www.oreilly.com/radar/bitcoin-and-the-disruption-of-monetary-oppression/#respond',
#    'published': 'Fri, 08 Nov 2019 05:10:27 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=8, tm_hour=5, tm_min=10, tm_sec=27, tm_wday=4, tm_yday=312, tm_isdst=0),
#    'authors': [{'name': 'Jenn Webb'}],
#    'author': 'Jenn Webb',
#    'author_detail': {'name': 'Jenn Webb'},
#    'tags': [{'term': 'Innovation & Disruption', 'scheme': None, 'label': None},
#     {'term': 'Deep Dive', 'scheme': None, 'label': None},
#     {'term': "Foo Camp '19", 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=9571',
#    'guidislink': False,
#    'summary': 'In this interview from O&#8217;Reilly Foo Camp 2019, Programming Bitcoin author Jimmy Song talks about why Bitcoin is a profound invention, the impact it&#8217;s already having on society, and its path to monetary relevance. Highlights from the interview include: In the physical world, we have centralized and decentralized scarcity—think numbered prints from artists (centralized) versus [&#8230;]',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'In this interview from O&#8217;Reilly Foo Camp 2019, Programming Bitcoin author Jimmy Song talks about why Bitcoin is a profound invention, the impact it&#8217;s already having on society, and its path to monetary relevance. Highlights from the interview include: In the physical world, we have centralized and decentralized scarcity—think numbered prints from artists (centralized) versus [&#8230;]'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p>In this interview from O&#8217;Reilly Foo Camp 2019, <a href="https://learning.oreilly.com/library/view/programming-bitcoin/9781492031482/"><em>Programming Bitcoin</em></a> author Jimmy Song talks about why Bitcoin is a profound invention, the impact it&#8217;s already having on society, and its path to monetary relevance.</p>\n\n<p>Highlights from the interview include:</p>\n\n<p>In the physical world, we have centralized and decentralized scarcity—think numbered prints from artists (centralized) versus gold or salt or glass beads (decentralized). Until Bitcoin, Song argues, there was no decentralized scarcity in the digital realm. &#8220;Decentralized digital scarcity is a profound invention,&#8221; Song explains &#8220;because it lets you transfer value without an intermediary. There is no permission involved, there&#8217;s no censorability, and that makes it an excellent, excellent [form of] money.&#8221; (<a href="#t=63">1:03</a>)</p>\n\n<p>One of the tangible social impacts of Bitcoin can be witnessed in the human rights arena. As one example, Song offers an overview of the refugee crisis in Venezuela, explaining that Bitcoin is allowing those wishing to flee the country to sell their belongings and retain their money when crossing the border to Columbia. &#8220;There&#8217;s very clear evidence of this,&#8221; Song explains &#8220;because the price of Bitcoin in Columbia is actually lower than everywhere else in the world because there&#8217;s such a big supply. Four million Venezuelans have left. That&#8217;s 10% of their population. That&#8217;s a serious impact. Usually in refugee crises, it has gotten so bad that people were willing to leave everything behind. With this, they get to carry their wealth. It undermines the Maduro government to a large degree.&#8221; (<a href="#t=351">5:51</a>)</p> \n\n<p>The US&#8217;s market-driven monetary imperialism has led, Song argues, to a sort of global US dollar hegemony—the impact of which is that all global trade is settled in US dollars; if you&#8217;re in Kenya and want to trade with someone in neighboring Nigeria, you have to trade for the US dollar and then back to the Kenyan shilling. Song notes this basically gives the US dominance over everything and allows dictators, who control their economies through their central banks, to use money as a tool of oppression. &#8220;Bitcoin gives you a politically neutral money, one that&#8217;s not dominated by a single country. I say all this about the US dollar, but imagine a world where the Chinese yuan is the dominant currency.&#8221; (<a href="#t=642">10:42</a>)</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/ENi7moVeFTY" height="1" width="1" alt=""/>'}],
#    'wfw_commentrss': 'https://www.oreilly.com/radar/bitcoin-and-the-disruption-of-monetary-oppression/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/bitcoin-and-the-disruption-of-monetary-oppression/'},
#   {'title': 'Four short links: 8 November 2019',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Four short links: 8 November 2019'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/VnkRZWuKkD0/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/VnkRZWuKkD0/',
#    'comments': 'https://www.oreilly.com/radar/four-short-links-8-november-2019/#respond',
#    'published': 'Fri, 08 Nov 2019 05:01:04 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=8, tm_hour=5, tm_min=1, tm_sec=4, tm_wday=4, tm_yday=312, tm_isdst=0),
#    'authors': [{'name': 'Nat Torkington'}],
#    'author': 'Nat Torkington',
#    'author_detail': {'name': 'Nat Torkington'},
#    'tags': [{'term': 'Four Short Links', 'scheme': None, 'label': None},
#     {'term': 'Signals', 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=10775',
#    'guidislink': False,
#    'summary': 'Probabilistic Scripts for Automating Common-Sense Tasks &#8212; In this talk, I&#8217;ll introduce a new declarative-programming approach for automating common-sense reasoning tasks: probabilistic scripting. A talk from Strange Loop. Infer &#8212; Facebook&#8217;s open source static analysis tool &#8212; if you give Infer some Java or C/C++/Objective-C code, it produces a list of potential bugs. VFRAME &#8212; [&#8230;]',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Probabilistic Scripts for Automating Common-Sense Tasks &#8212; In this talk, I&#8217;ll introduce a new declarative-programming approach for automating common-sense reasoning tasks: probabilistic scripting. A talk from Strange Loop. Infer &#8212; Facebook&#8217;s open source static analysis tool &#8212; if you give Infer some Java or C/C++/Objective-C code, it produces a list of potential bugs. VFRAME &#8212; [&#8230;]'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<ol><li><a href="https://www.youtube.com/watch?v=MiiWzJE0fEA">Probabilistic Scripts for Automating Common-Sense Tasks</a> &#8212; <em>In this talk, I&#8217;ll introduce a new declarative-programming approach for automating common-sense reasoning tasks: probabilistic scripting.</em> A <a href="https://thestrangeloop.com/2019/probabilistic-scripts-for-automating-common-sense-tasks.html">talk</a> from Strange Loop.</li><li><a href="https://fbinfer.com/">Infer</a> &#8212; Facebook&#8217;s <a href="http://github.com/facebook/infer">open source</a> <em>static analysis tool &#8212; if you give Infer some Java or C/C++/Objective-C code, it produces a list of potential bugs</em>.</li><li><a href="https://ahprojects.com/vframe/">VFRAME</a> &#8212; <em>Visual Forensics and Metadata Extraction is a computer vision toolkit designed for human rights researchers. It aims to bridge the gap between state-of-the-art artificial intelligence used in the commercial sector and make it accessible and tailored to the needs of human rights researchers and investigative journalists working with large video or image datasets.</em></li><li><a href="https://arxiv.org/pdf/1909.02638.pdf">(Un)informed Consent: Studying GDPR Consent Notices in the Field</a> &#8212; Most GDPR consent forms come with pre-checked boxes. Cut to section 4.5, &#8220;Survey Results,&#8221; of this paper for the (not at all) astonishingly low number of people who will click a checkbox to get personalization: 0.4%. (via <a href="https://twitter.com/random_walker/status/1187391482401038336">Arvind Narayanan</a>)</li></ol>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/VnkRZWuKkD0" height="1" width="1" alt=""/>'}],
#    'wfw_commentrss': 'https://www.oreilly.com/radar/four-short-links-8-november-2019/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/four-short-links-8-november-2019/'},
#   {'title': 'Highlights from the O’Reilly Software Architecture Conference in Berlin 2019',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Highlights from the O’Reilly Software Architecture Conference in Berlin 2019'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/XFnuaWaXgQI/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/XFnuaWaXgQI/',
#    'comments': 'https://www.oreilly.com/radar/highlights-from-software-architecture-berlin-2019/#respond',
#    'published': 'Thu, 07 Nov 2019 20:10:44 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=7, tm_hour=20, tm_min=10, tm_sec=44, tm_wday=3, tm_yday=311, tm_isdst=0),
#    'authors': [{'name': 'Mac Slocum'}],
#    'author': 'Mac Slocum',
#    'author_detail': {'name': 'Mac Slocum'},
#    'tags': [{'term': 'Next Architecture', 'scheme': None, 'label': None},
#     {'term': 'Signals', 'scheme': None, 'label': None},
#     {'term': 'Software Architecture Berlin 2019',
#      'scheme': None,
#      'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=10569',
#    'guidislink': False,
#    'summary': 'Experts from across the software architecture world came together in Berlin for the O&#8217;Reilly Software Architecture Conference. Below you&#8217;ll find links to highlights from the event. Cognitive biases in the architect&#8217;s life Birgitta Boeckeler covers some of the cognitive biases that can trip up architects. Watch &#8220;Cognitive biases in the architect&#8217;s life&#8220; The three-headed dog: [&#8230;]',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Experts from across the software architecture world came together in Berlin for the O&#8217;Reilly Software Architecture Conference. Below you&#8217;ll find links to highlights from the event. Cognitive biases in the architect&#8217;s life Birgitta Boeckeler covers some of the cognitive biases that can trip up architects. Watch &#8220;Cognitive biases in the architect&#8217;s life&#8220; The three-headed dog: [&#8230;]'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p>Experts from across the software architecture world came together in Berlin for the <a href="https://conferences.oreilly.com/software-architecture/sa-eu">O&#8217;Reilly Software Architecture Conference</a>. Below you&#8217;ll find links to highlights from the event.</p>\n<h2>Cognitive biases in the architect&#8217;s life</h2>\n<p>Birgitta Boeckeler covers some of the cognitive biases that can trip up architects.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/cognitive-biases-in-the-architects-life">Cognitive biases in the architect&#8217;s life</a>&#8220;</li>\n</ul>\n<h2>The three-headed dog: Architecture, process, structure</h2>\n<p>Allen Holub shows you how architecture, process, and structure interact, and how to fix misalignment that’s sucking the life out of your productivity.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/the-three-headed-dog-architecture-process-structure">The three-headed dog: Architecture, process, structure</a>&#8220;</li>\n</ul>\n<h2>Modern machine learning architectures: Data and hardware and platform, oh my</h2>\n<p>Brian Sletten takes a deep dive into the intersection of data, models, hardware, language, architecture, and machine learning systems.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/modern-machine-learning-architectures">Modern machine learning architectures: Data and hardware and platform, oh my</a>&#8220;</li>\n</ul>\n<h2>From the trenches: Patrick Kua</h2>\n<p>Neal Ford interviews Patrick Kua about his career path and his work as an architect.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/from-the-trenches-patrick-kua">From the trenches: Patrick Kua</a>&#8220;</li>\n</ul>\n<h2>The new norms of cloud native</h2>\n<p>Cheryl Hung discusses the state of cloud native tools and communities.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/the-new-norms-of-cloud-native">The new norms of cloud native</a>&#8220;</li>\n</ul>\n<div class="hidden">\n<!--unsigned--></p>\n<h2>Next data platform architecture: Distributed Data Mesh</h2>\n<p>Zhamak Dehghani introduces data mesh, the next-generation data platform that draws from modern distributed architecture.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/next-data-platform-architecture-distributed-data-mesh">Next data platform architecture: Distributed Data Mesh</a>&#8220;</li>\n</ul>\n</div>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/XFnuaWaXgQI" height="1" width="1" alt=""/>'}],
#    'wfw_commentrss': 'https://www.oreilly.com/radar/highlights-from-software-architecture-berlin-2019/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/highlights-from-software-architecture-berlin-2019/'},
#   {'title': 'Highlights from the O’Reilly Velocity Conference in Berlin 2019',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Highlights from the O’Reilly Velocity Conference in Berlin 2019'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/V2KqZ95Mbgs/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/V2KqZ95Mbgs/',
#    'comments': 'https://www.oreilly.com/radar/highlights-from-velocity-berlin-2019/#respond',
#    'published': 'Thu, 07 Nov 2019 20:09:07 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=7, tm_hour=20, tm_min=9, tm_sec=7, tm_wday=3, tm_yday=311, tm_isdst=0),
#    'authors': [{'name': 'Mac Slocum'}],
#    'author': 'Mac Slocum',
#    'author_detail': {'name': 'Mac Slocum'},
#    'tags': [{'term': 'Next Architecture', 'scheme': None, 'label': None},
#     {'term': 'Signals', 'scheme': None, 'label': None},
#     {'term': 'Velocity Conference Berlin 2019',
#      'scheme': None,
#      'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=10577',
#    'guidislink': False,
#    'summary': 'People from across the cloud native and distributed systems worlds came together in Berlin for the O&#8217;Reilly Velocity Conference. Below you&#8217;ll find links to highlights from the event. My love letter to computer science is very short and I also forgot to mail it James Mickens shares his concerns and frustrations with today&#8217;s technology. Watch [&#8230;]',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'People from across the cloud native and distributed systems worlds came together in Berlin for the O&#8217;Reilly Velocity Conference. Below you&#8217;ll find links to highlights from the event. My love letter to computer science is very short and I also forgot to mail it James Mickens shares his concerns and frustrations with today&#8217;s technology. Watch [&#8230;]'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p>People from across the cloud native and distributed systems worlds came together in Berlin for the <a href="https://conferences.oreilly.com/velocity/vl-eu">O&#8217;Reilly Velocity Conference</a>. Below you&#8217;ll find links to highlights from the event.</p>\n<h2>My love letter to computer science is very short and I also forgot to mail it</h2>\n<p>James Mickens shares his concerns and frustrations with today&#8217;s technology.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/my-love-letter-to-computer-science-is-very-short">My love letter to computer science is very short and I also forgot to mail ity</a>&#8220;</li>\n</ul>\n<h2>Everything is a little bit broken; or, The illusion of control</h2>\n<p>Heidi Waterhouse outlines ways to handle uncertainty by adding in error budgets, layered access, and other accommodations for failure.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/everything-is-a-little-bit-broken">Everything is a little bit broken; or, The illusion of control</a>&#8220;</li>\n</ul>\n<h2>Observability: Understanding production through your customers&#8217; eyes</h2>\n<p>Christine Yen says observability isn’t just for ops folks, but it’s not only about engineering roles, either.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/observability-understanding-production-through-your-customers-eyes">Observability: Understanding production through your customers&#8217; eyes</a>&#8220;</li>\n</ul>\n<h2>Secure reliable systems</h2>\n<p>Ana Oprea provides insights and strategies for baking security into your systems.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/secure-reliable-systems-velocity-eu-19">Secure reliable systems</a>&#8220;</li>\n</ul>\n<h2>How to deploy infrastructure in just 13.8 billion years</h2>\n<p>Ingrid Burrington looks at how reframing the time scales of computation can change the way your build infrastructure.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/how-to-deploy-infrastructure-in-just-13-point-8-billion-years">How to deploy infrastructure in just 13.8 billion years</a>&#8220;</li>\n</ul>\n<h2>The ultimate guide to complicated systems</h2>\n<p>Jennifer Davis explores how sustainable engineering practices can enable technical and strategic direction.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/the-ultimate-guide-to-complicated-systems">The ultimate guide to complicated systems</a>&#8220;</li>\n</ul>\n<h2>5 things Go taught me about open source?</h2>\n<p>Dave Cheney talks about the unexpected things he learned while trying to convince programmers to try Go.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/5-things-go-taught-me-about-open-source">5 things Go taught me about open source?</a>&#8220;</li>\n</ul>\n<h2>Building high-performing engineering teams, one pixel at a time</h2>\n<p>Lena Reinhard discusses ways you can make distributed teams strong, deliberate, and productive.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/building-high-performing-engineering-teams-one-pixel-at-a-time">Building high-performing engineering teams, one pixel at a time</a>&#8220;</li>\n</ul>\n<h2>Controlled chaos: The inevitable marriage of DevOps and security</h2>\n<p>Kelly Shortridge explains why chaos and resilience engineering represent the future of security programs.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/controlled-chaos-the-inevitable-marriage-of-devops-and-security">Controlled chaos: The inevitable marriage of DevOps and security</a>&#8220;</li>\n</ul>\n<div class="hidden">\n<!--unsigned--></p>\n<h2>The power of good abstractions in systems design</h2>\n<p>Lorenzo Saino looks at how good abstractions make it possible to identify and apply solutions to seemingly unrelated problems.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/the-power-of-good-abstractions-in-systems-design">The powe ...
#    'wfw_commentrss': 'https://www.oreilly.com/radar/highlights-from-velocity-berlin-2019/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/highlights-from-velocity-berlin-2019/'},
#   {'title': 'From the trenches: Patrick Kua',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'From the trenches: Patrick Kua'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/0JSKwm4FfEE/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/0JSKwm4FfEE/',
#    'comments': 'https://www.oreilly.com/radar/from-the-trenches-patrick-kua/#respond',
#    'published': 'Thu, 07 Nov 2019 20:00:48 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=7, tm_hour=20, tm_min=0, tm_sec=48, tm_wday=3, tm_yday=311, tm_isdst=0),
#    'authors': [{'name': 'Patrick Kua and Neal Ford'}],
#    'author': 'Patrick Kua and Neal Ford',
#    'author_detail': {'name': 'Patrick Kua and Neal Ford'},
#    'tags': [{'term': 'Next Architecture', 'scheme': None, 'label': None},
# ...
#    'wfw_commentrss': 'https://www.oreilly.com/radar/controlled-chaos-the-inevitable-marriage-of-devops-and-security/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/controlled-chaos-the-inevitable-marriage-of-devops-and-security/'},
#   {'title': 'The ultimate guide to complicated systems',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'The ultimate guide to complicated systems'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/AlXZ2UUW79M/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/AlXZ2UUW79M/',
#    'comments': 'https://www.oreilly.com/radar/the-ultimate-guide-to-complicated-systems/#respond',
#    'published': 'Thu, 07 Nov 2019 20:00:17 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=7, tm_hour=20, tm_min=0, tm_sec=17, tm_wday=3, tm_yday=311, tm_isdst=0),
#    'authors': [{'name': 'Jennifer Davis'}],
#    'author': 'Jennifer Davis',
#    'author_detail': {'name': 'Jennifer Davis'},
#    'tags': [{'term': 'Next Architecture', 'scheme': None, 'label': None},
#     {'term': 'Velocity Conference Berlin 2019',
#      'scheme': None,
#      'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=10540',
#    'guidislink': False,
#    'summary': 'This is a keynote highlight from the O&#8217;Reilly Velocity Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'This is a keynote highlight from the O&#8217;Reilly Velocity Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p>This is a keynote highlight from the O&#8217;Reilly Velocity Conference in Berlin 2019. <a href="https://learning.oreilly.com/videos/oreilly-velocity-conference/9781492050742/9781492050742-video328466">Watch the full version of this keynote on the O&#8217;Reilly online learning platform</a>.</p>\n<p>You can also <a href="https://www.oreilly.com/radar/highlights-from-velocity-berlin-2019">see other highlights from the event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/AlXZ2UUW79M" height="1" width="1" alt=""/>'}],
#    'wfw_commentrss': 'https://www.oreilly.com/radar/the-ultimate-guide-to-complicated-systems/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/the-ultimate-guide-to-complicated-systems/'},
#   {'title': 'Cognitive biases in the architect’s life',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Cognitive biases in the architect’s life'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/MCKQixUPlMQ/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/MCKQixUPlMQ/',
#    'comments': 'https://www.oreilly.com/radar/cognitive-biases-in-the-architects-life/#respond',
#    'published': 'Thu, 07 Nov 2019 20:00:07 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=7, tm_hour=20, tm_min=0, tm_sec=7, tm_wday=3, tm_yday=311, tm_isdst=0),
#    'authors': [{'name': 'Birgitta Boeckeler'}],
#    'author': 'Birgitta Boeckeler',
#    'author_detail': {'name': 'Birgitta Boeckeler'},
#    'tags': [{'term': 'Next Architecture', 'scheme': None, 'label': None},
#     {'term': 'Software Architecture Berlin 2019',
#      'scheme': None,
#      'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=10497',
#    'guidislink': False,
#    'summary': 'This is a keynote highlight from the O&#8217;Reilly Software Architecture Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'This is a keynote highlight from the O&#8217;Reilly Software Architecture Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p>This is a keynote highlight from the O&#8217;Reilly Software Architecture Conference in Berlin 2019. <a href="https://learning.oreilly.com/videos/oreilly-software-architecture/9781492050728/9781492050728-video328591">Watch the full version of this keynote on the O&#8217;Reilly online learning platform</a>.</p>\n<p>You can also <a href="https://www.oreilly.com/radar/highlights-from-software-architecture-berlin-2019">see other highlights from the event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/MCKQixUPlMQ" height="1" width="1" alt=""/>'}],
#    'wfw_commentrss': 'https://www.oreilly.com/radar/cognitive-biases-in-the-architects-life/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/cognitive-biases-in-the-architects-life/'},
#   {'title': 'The three-headed dog: Architecture, process, structure',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'The three-headed dog: Architecture, process, structure'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/tUBOtwDRLBU/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/tUBOtwDRLBU/',
#    'comments': 'https://www.oreilly.com/radar/the-three-headed-dog-architecture-process-structure/#respond',
#    'published': 'Thu, 07 Nov 2019 20:00:06 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=7, tm_hour=20, tm_min=0, tm_sec=6, tm_wday=3, tm_yday=311, tm_isdst=0),
#    'authors': [{'name': 'Allen Holub'}],
#    'author': 'Allen Holub',
#    'author_detail': {'name': 'Allen Holub'},
#    'tags': [{'term': 'Next Architecture', 'scheme': None, 'label': None},
#     {'term': 'Software Architecture Berlin 2019',
#      'scheme': None,
#      'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=10490',
#    'guidislink': False,
#    'summary': 'This is a keynote highlight from the O&#8217;Reilly Software Architecture Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'This is a keynote highlight from the O&#8217;Reilly Software Architecture Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p>This is a keynote highlight from the O&#8217;Reilly Software Architecture Conference in Berlin 2019. <a href="https://learning.oreilly.com/videos/oreilly-software-architecture/9781492050728/9781492050728-video328592">Watch the full version of this keynote on the O&#8217;Reilly online learning platform</a>.</p>\n<p>You can also <a href="https://www.oreilly.com/radar/highlights-from-software-architecture-berlin-2019">see other highlights from the event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/tUBOtwDRLBU" height="1" width="1" alt=""/>'}],
#    'wfw_commentrss': 'https://www.oreilly.com/radar/the-three-headed-dog-architecture-process-structure/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/the-three-headed-dog-architecture-process-structure/'},
#   {'title': 'A world of deepfakes',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'A world of deepfakes'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9PQAmHRa6oA/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9PQAmHRa6oA/',
#    'comments': 'https://www.oreilly.com/radar/a-world-of-deepfakes/#respond',
#    'published': 'Thu, 07 Nov 2019 14:00:50 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=7, tm_hour=14, tm_min=0, tm_sec=50, tm_wday=3, tm_yday=311, tm_isdst=0),
#    'authors': [{'name': 'Ben Lorica and Mike Loukides'}],
#    'author': 'Ben Lorica and Mike Loukides',
#    'author_detail': {'name': 'Ben Lorica and Mike Loukides'},
#    'tags': [{'term': 'AI & ML', 'scheme': None, 'label': None},
#     {'term': 'Deep Dive', 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=10617',
#    'guidislink': False,
#    'summary': 'Deepfakes have been very much in the news for the past two years. It’s time to think about what deepfakes are and what they mean. Where do they come from? Why now? Is this just a natural evolution in the history of technology? Deepfakes are media that are created by AI. They appear to be [&#8230;]',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Deepfakes have been very much in the news for the past two years. It’s time to think about what deepfakes are and what they mean. Where do they come from? Why now? Is this just a natural evolution in the history of technology? Deepfakes are media that are created by AI. They appear to be [&#8230;]'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p>Deepfakes have been very much in the news for the past two years. It’s time to think about what deepfakes are and what they mean. Where do they come from? Why now? Is this just a natural evolution in the history of technology?</p>\n\n\n\n<p>Deepfakes are media that are created by AI. They appear to be genuine (e.g., a <a href="https://www.theverge.com/tldr/2018/4/17/17247334/ai-fake-news-video-barack-obama-jordan-peele-buzzfeed">video of President Obama</a>) but have limited connection to reality. An audio track can be created that sounds indistinguishable from the victim, saying something the victim would never have said. Video can be generated from existing videos or photos that match the soundtrack, so that the mouth moves correctly and the facial expressions look natural. It’s not surprising that humans have trouble detecting fakes; with the current technology, even shallow fakes are too good.</p>\n\n\n\n<p>Deepfakes are the logical extension of older AI research. It wasn’t long ago that we read about AI generating new paintings in the style of <a href="https://www.pcworld.com/article/3053520/ai-just-3d-printed-a-brand-new-rembrandt-and-its-shockingly-good.html">Rembrandt</a> and other Dutch Masters, stylizing pictures in the style of <a href="https://qz.com/495614/computers-can-now-paint-like-van-gogh-and-picasso/">Van Gogh and Picasso</a>, and so on. At the time, there was more concern about the future of human creativity: would we still need artists? Would we live in a world full of fake Van Goghs? We shrugged those “fakes” off because we were asking the wrong questions. We don’t need more Van Goghs any more than we need more <a href="https://en.wikipedia.org/wiki/Velvet_Elvis">Elvises on velvet</a>. We may end up with a few fake Rembrandts where they shouldn’t be, but the art world will survive.</p>\n\n\n\n<p>If that’s the wrong question, what’s the right one? The problem with deepfakes is that simulating an artist’s style collided with the rise of fake news. Fake news isn’t new by any means; there have always been conspiracy theorists who are marvelously skeptical of “traditional” media, but are completely unskeptical of their own sources, whether they claim that Tibetans are spying on us through a system of underground tunnels or that vaccinations cause autism.</p>\n\n\n\n<p>To this collision, add three more factors: the democratization of AI, the decrease in the cost of computing power, and the phenomenon of virality. Deepfakes jumped out of the lab and into the streets. You don’t need a Ph.D. to generate fake media, nor do you need the resources of a nation state to acquire enough computing power. Some easily available tools and a credit card to buy time on AWS are all you need. In some cases, it only takes an app: in China, a popular iPhone app <a href="https://www.theverge.com/2019/9/2/20844338/zao-deepfake-app-movie-tv-show-face-replace-privacy-policy-concerns">lets you put your face into movie clips</a>. (Ironically, backlash against this app didn’t take place because of the fakes but because of the app’s privacy policy.) Once you’ve created a fake, you can use social media to propagate it. YouTube’s and Facebook’s algorithms for optimizing “engagement” can make any content viral in seconds.</p>\n\n\n\n<p>That all adds up to a scary picture. We will certainly see deepfakes in politics, though as security expert @thegrugq <a href="https://medium.com/@thegrugq/cheap-fakes-beat-deep-fakes-b1ac91e44837">points out</a>, cheap fakes are better than deepfakes for shaping public opinion. Deepfakes might be more dangerous in computer security, where they can be used to circumvent authentication or perform high-quality phishing attacks. Symantec <a href="https://www.ft.com/content/63cd4010-bfce-11e9-b350-db00d509634e">has reported</a> that it has seen such attacks in the field, and recently an <a href="https://beta.washingtonpost.com/technology/2019/09/04/an-artificial-intelligence-first-voice-mimicking ...
#    'wfw_commentrss': 'https://www.oreilly.com/radar/a-world-of-deepfakes/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/a-world-of-deepfakes/'}],
#  'bozo': 0,
#  'headers': {'Content-Type': 'text/xml; charset=UTF-8',
#   'ETag': '6VAO07qGw2ywwBG4BxLAuCT1URo',
#   'Last-Modified': 'Wed, 13 Nov 2019 21:17:13 GMT',
#   'Content-Encoding': 'gzip',
#   'Transfer-Encoding': 'chunked',
#   'Date': 'Wed, 13 Nov 2019 22:41:48 GMT',
#   'Expires': 'Wed, 13 Nov 2019 22:41:48 GMT',
#   'Cache-Control': 'private, max-age=0',
#   'X-Content-Type-Options': 'nosniff',
#   'X-XSS-Protection': '1; mode=block',
#   'Server': 'GSE',
#   'Connection': 'close'},
#  'etag': '6VAO07qGw2ywwBG4BxLAuCT1URo',
#  'updated': 'Wed, 13 Nov 2019 21:17:13 GMT',
#  'updated_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=13, tm_hour=21, tm_min=17, tm_sec=13, tm_wday=2, tm_yday=317, tm_isdst=0),
#  'href': 'http://feeds.feedburner.com/oreilly/radar/atom',
#  'status': 200,
#  'encoding': 'UTF-8',
#  'version': 'rss20',
#  'namespaces': {'content': 'http://purl.org/rss/1.0/modules/content/',
#   'wfw': 'http://wellformedweb.org/CommentAPI/',
#   'dc': 'http://purl.org/dc/elements/1.1/',
#   '': 'http://www.w3.org/2005/Atom',
#   'sy': 'http://purl.org/rss/1.0/modules/syndication/',
#   'slash': 'http://purl.org/rss/1.0/modules/slash/',
#   'geo': 'http://www.w3.org/2003/01/geo/wgs84_pos#',
#   'feedburner': 'http://rssnamespace.org/feedburner/ext/1.0'}}

# %% [markdown]
# ### 2. Obtain a list of components (keys) that are available for this feed.

# %%
rss.keys()
# Out:
# dict_keys(['feed', 'entries', 'bozo', 'headers', 'etag', 'updated', 'updated_parsed', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %% [markdown]
# ### 3. Obtain a list of components (keys) that are available for the *feed* component of this RSS feed.

# %%
rss.feed.keys()
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'subtitle', 'subtitle_detail', 'updated', 'updated_parsed', 'language', 'sy_updateperiod', 'sy_updatefrequency', 'generator_detail', 'generator', 'feedburner_info', 'geo_lat', 'geo_long', 'feedburner_emailserviceid', 'feedburner_feedburnerhostname'])

# %% [markdown]
# ### 4. Extract and print the feed title, subtitle, author, and link.

# %%
print (rss.feed.title)
print ('')
print (rss.feed.subtitle)
print ('')
print (rss.feed.link)
# Out:
# Radar
#
# Now, next, and beyond: Tracking need-to-know trends at the intersection of business and technology
#
# https://www.oreilly.com/radar

# %% [markdown]
# ### 5. Count the number of entries that are contained in this RSS feed.

# %%
rss.entries
# Out:
# [{'title': 'Four short links: 13 November 2019',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'Four short links: 13 November 2019'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/ID1RcQfYgOk/'}],
#   'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/ID1RcQfYgOk/',
#   'comments': 'https://www.oreilly.com/radar/four-short-links-13-november-2019/#respond',
#   'published': 'Wed, 13 Nov 2019 05:01:22 +0000',
#   'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=13, tm_hour=5, tm_min=1, tm_sec=22, tm_wday=2, tm_yday=317, tm_isdst=0),
#   'authors': [{'name': 'Nat Torkington'}],
#   'author': 'Nat Torkington',
#   'author_detail': {'name': 'Nat Torkington'},
#   'tags': [{'term': 'Four Short Links', 'scheme': None, 'label': None},
#    {'term': 'Signals', 'scheme': None, 'label': None}],
#   'id': 'https://www.oreilly.com/radar/?p=10848',
#   'guidislink': False,
#   'summary': 'Learning to Smell: Using Deep Learning to Predict the Olfactory Properties of Molecules (Google) &#8212; a readable walk through of how they model and make sense of smells. Diversified Sampling: Mining Large Datasets for Special Cases &#8212; TL;DR: the objective is to build a small sample of the data in which special cases are likely [&#8230;]',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'Learning to Smell: Using Deep Learning to Predict the Olfactory Properties of Molecules (Google) &#8212; a readable walk through of how they model and make sense of smells. Diversified Sampling: Mining Large Datasets for Special Cases &#8212; TL;DR: the objective is to build a small sample of the data in which special cases are likely [&#8230;]'},
#   'content': [{'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': '<ol><li><a href="https://ai.googleblog.com/2019/10/learning-to-smell-using-deep-learning.html">Learning to Smell: Using Deep Learning to Predict the Olfactory Properties of Molecules</a> (Google) &#8212; a readable walk through of how they model and make sense of smells.</li><li><a href="https://vvvvalvalval.github.io/posts/2019-09-13-diversified-sampling-mining-large-datasets-for-special-cases.html">Diversified Sampling: Mining Large Datasets for Special Cases</a> &#8212; <em>TL;DR: the objective is to build a small sample of the data in which special cases are likely to be represented. The strategy is to have each data item emit a list of &#8220;features,&#8221; and to boost the probability of selecting rare features. A shallow understanding of the data is often enough to design an effective features extraction.</em></li><li><a href="https://github.com/datamllab/rlcard">RLCard</a> &#8212; open source reinforcement learning toolkit for card games. <a href="https://arxiv.org/pdf/1910.04376.pdf">Paper</a>. (via <a href="https://medium.com/syncedreview/texas-a-m-and-simon-fraser-universities-open-source-rl-toolkit-for-card-games-858e22195f36">SyncedReview</a>)</li><li><a href="https://github.com/xo/usql">usql</a> &#8212; <em>Universal command-line interface for SQL databases</em>.</li></ol>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/ID1RcQfYgOk" height="1" width="1" alt=""/>'}],
#   'wfw_commentrss': 'https://www.oreilly.com/radar/four-short-links-13-november-2019/feed/',
#   'slash_comments': '0',
#   'feedburner_origlink': 'https://www.oreilly.com/radar/four-short-links-13-november-2019/'},
#  {'title': 'O’Reilly serverless survey 2019: Concerns, what works, and what to expect',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'O’Reilly serverless survey 2019: Concerns, what works, and what to expect'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/Tpz60LEjmU4/'}],
#   'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/Tpz60LEjmU4/',
#   'comments': 'https://www.oreilly.com/radar/oreilly-serverless-survey-2019-concerns-what-works-and-what-to-expect/#respond',
#   'published': 'Tue, 12 Nov 2019 12:00:41 +0000',
#   'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=12, tm_hour=12, tm_min=0, tm_sec=41, tm_wday=1, tm_yday=316, tm_isdst=0),
#   'authors': [{'name': 'Roger Magoulas and Chris Guzikowski'}],
#   'author': 'Roger Magoulas and Chris Guzikowski',
#   'author_detail': {'name': 'Roger Magoulas and Chris Guzikowski'},
#   'tags': [{'term': 'Next Architecture', 'scheme': None, 'label': None},
#    {'term': 'Research', 'scheme': None, 'label': None}],
#   'id': 'https://www.oreilly.com/radar/?p=9819',
#   'guidislink': False,
#   'summary': 'For the inaugural O’Reilly survey on serverless architecture adoption, we were pleasantly surprised at the high level of response: more than 1,500 respondents from a wide range of locations, companies, and industries participated. The high response rate tells us that serverless is garnering significant mindshare in the community.1 Key findings from the survey include: 40% [&#8230;]',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'For the inaugural O’Reilly survey on serverless architecture adoption, we were pleasantly surprised at the high level of response: more than 1,500 respondents from a wide range of locations, companies, and industries participated. The high response rate tells us that serverless is garnering significant mindshare in the community.1 Key findings from the survey include: 40% [&#8230;]'},
#   'content': [{'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': '<p><p id="F1">For the inaugural O’Reilly survey on serverless architecture adoption, we were pleasantly surprised at the high level of response: more than 1,500 respondents from a wide range of locations, companies, and industries participated. The high response rate tells us that serverless is garnering significant mindshare in the community.<a href="#_ftn1"><sup>1</sup></a></p>\n\n\n\n<p>Key findings from the survey include:</p>\n\n\n\n<ul><li>40% of respondents work at organizations that have adopted serverless architecture in some form or another. Reduced operational costs and automatic scaling are the top serverless benefits cited by this group.</li><li>Of the 60% of respondents whose companies haven&#8217;t adopted serverless, the leading concerns about the paradigm are security and fear of the unknown.</li><li>About 50% of respondents who adopted serverless three-plus years ago consider their implementations successful or extremely successful, a contrast to the 35% of those adopting serverless a year or less ago experiencing a successful or extremely successful implementation—a gap that suggests serverless experience pays off.</li><li>Respondents who have implemented serverless made custom tooling the top tool choice—implying that vendors’ tools may not fully address what organizations need to deploy and manage a serverless infrastructure.</li></ul>\n\n\n\n<p>In our analysis, we assigned experience levels to our respondents for some of the survey questions. New respondents work at organizations that have tried serverless for less than one year. Early respondents’ organizations have employed serverless for one to three years. Sophisticated respondents work at organizations that have been using serverless for more than three years.</p>\n\n\n\n<h2>What respondents do and where they work</h2>\n\n\n\n<figure class="wp-block-image"><img src="https://www.oreilly.com/radar/wp-content/uploads/sites/3/2019/10/Figure1-e1570028458892-1048x647.png" alt="Serverless Survey figure 1" class="wp-image-9803" srcset="https://www.oreilly.com/radar/wp-content/uploads/sites/3/2019/10/Figure1-e1570028458892-1048x647.png 1048w, https://www.oreilly.com/radar/wp-content/uploads/sites/3/2019/10/Figure1-e1570028458892-300x185.png 300w, https://www.oreilly.com/radar/wp-content/uploads/sites/3/2019/10/Figure1-e1570028458892-768x474.png 768w, https://www.oreilly.com/radar/wp-content/uploads/sites/3/2019/10/Figure1-e1570028458892.png 1400w" sizes="(max-width: 1048px) 100vw, 1048px" /><figcaption>Figure 1. Roles of survey respondents.</figcaption></figure>\n\n\n\n<p>Looking at the role distribution among respondents, we see that those exploring and using the serverless paradigm are not confined to a single role. We suspect this points to a general drift toward software teams taking more responsibility for infrastructure, and increasingly, enabled by serverless options.</p>\n\n\n\n<figure class="wp-block-image"><img src="https://www.oreilly.com/radar/wp-content/uploads/sites/3/2019/10/Figure2-1048x711.png" alt="Serverless Survey figure 2" class="wp-image-9804" srcset="https://www.oreilly.com/radar/wp-content/uploads/sites/3/2019/10/Figure2-1048x711.png 1048w, https://www.oreilly.com/radar/wp-content/uploads/sites/3/2019/10/Figure2-300x204.png 300w, https://www.oreilly.com/radar/wp-content/uploads/sites/3/2019/10/Figure2-768x521.png 768w, https://www.oreilly.com/radar/wp-content/uploads/sites/3/2019/10/Figure2.png 1400w" sizes="(max-width: 1048px) 100vw, 1048px" /><figcaption>Figure 2. Industries of survey respondents.</figcaption></figure>\n\n\n\n<p>More than a fifth of the respondents work in the software industry—skewing results toward the concerns of software companies, and helping explain the preponderance of those with software engineering roles.</p>\n\n\n\n<p>Finance and banking, the vertical with the second highest share of respondents, may include the growing number of fintech startups that, with no burden of legacy infrastructure,  ...
#   'wfw_commentrss': 'https://www.oreilly.com/radar/oreilly-serverless-survey-2019-concerns-what-works-and-what-to-expect/feed/',
#   'slash_comments': '0',
#   'feedburner_origlink': 'https://www.oreilly.com/radar/oreilly-serverless-survey-2019-concerns-what-works-and-what-to-expect/'},
#  {'title': 'Improving the military UX',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'Improving the military UX'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/XeRPWuPwIDk/'}],
#   'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/XeRPWuPwIDk/',
#   'comments': 'https://www.oreilly.com/radar/improving-the-military-ux/#respond',
#   'published': 'Tue, 12 Nov 2019 05:10:49 +0000',
#   'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=12, tm_hour=5, tm_min=10, tm_sec=49, tm_wday=1, tm_yday=316, tm_isdst=0),
#   'authors': [{'name': 'Jenn Webb'}],
#   'author': 'Jenn Webb',
#   'author_detail': {'name': 'Jenn Webb'},
#   'tags': [{'term': 'Innovation & Disruption', 'scheme': None, 'label': None},
#    {'term': 'Deep Dive', 'scheme': None, 'label': None},
#    {'term': "Foo Camp '19", 'scheme': None, 'label': None}],
#   'id': 'https://www.oreilly.com/radar/?p=9575',
#   'guidislink': False,
#   'summary': 'In this interview from O&#8217;Reilly Foo Camp 2019, Noah Firth, director at the Air Force Digital Service, talks about the challenges of making the US military more user-friendly, the unique recruiting parameters for team members, and the success metrics that guide his team. Highlights from this interview include: Firth&#8217;s team&#8217;s main focus is on how [&#8230;]',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'In this interview from O&#8217;Reilly Foo Camp 2019, Noah Firth, director at the Air Force Digital Service, talks about the challenges of making the US military more user-friendly, the unique recruiting parameters for team members, and the success metrics that guide his team. Highlights from this interview include: Firth&#8217;s team&#8217;s main focus is on how [&#8230;]'},
#   'content': [{'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': '<p>In this interview from O&#8217;Reilly Foo Camp 2019, Noah Firth, director at the Air Force Digital Service, talks about the challenges of making the US military more user-friendly, the unique recruiting parameters for team members, and the success metrics that guide his team.</p>\n\n<p>Highlights from this interview include:</p>\n\n<p>Firth&#8217;s team&#8217;s main focus is on how technology can be used to improve the lives of US military service members and their families. He describes the significance of a large project they&#8217;re wrapping up, move.mil. &#8220;Military service members have to move every two to four years, and the system that was enabling those moves was generally hostile toward the user experience. We&#8217;re working to use modern technologies to implement a new-and-improved system to schedule the moves to allow service members&#8217; spouses and family members to be active participants in figuring out how they&#8217;re going to uproot their lives and move across the country or around the world.&#8221; (<a href="#t=2">00:02</a>)</p>\n\n<p>Recruiting is a challenge for any organization, but it&#8217;s particularly quirky for teams working with government organizations, Firth explains. He looks for folks who are not only at the top of their fields, but for those able to maneuver around the frustrations of slow-moving bureaucracy. &#8220;We have what we call core competencies&mdash;questions we ask and things we look for to determine whether or not someone&#8217;s going to be a good fit in our organization. &#8230; Some of those things that we call &#8217;emotional quotient&#8217; are as important if not more so than some of the technical quotient things we&#8217;re looking for. &#8230; We have to go through an enormous amount of validation of a person&#8217;s prior experiences, but then also a validation of them as a human. It gives us the ability to do the whole person concept, to make sure that, as we have a small team and we have to maintain a small team, we can work to make that small team work well together.&#8221; (<a href="#t=57">00:57</a>)\n\n<p>One might think it wouldn&#8217;t be difficult, Firth notes, but one of the main success metrics he uses is whether or not they can convince others that technology can make their lives better. Also in Firth&#8217;s case, the military leadership he deals with turns over every two to four years; all around, he&#8217;s on a &#8220;constant education campaign.&#8221; Firth outlines how he measures overall success: &#8220;Have we made the user&#8217;s life better? Have we used technology to do so in a way that appreciates (1) the capability of the technology, but also (2), the capability of the people who are implementing that technology and will have to do so long term? Then (3), have we walked away leaving behind us a legacy of creating that understanding of what technology could be used for?&#8221; (<a href="#t=198">03:18</a>)</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/XeRPWuPwIDk" height="1" width="1" alt=""/>'}],
#   'wfw_commentrss': 'https://www.oreilly.com/radar/improving-the-military-ux/feed/',
#   'slash_comments': '0',
#   'feedburner_origlink': 'https://www.oreilly.com/radar/improving-the-military-ux/'},
#  {'title': 'Four short links: 12 November 2019',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'Four short links: 12 November 2019'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/EfPiWqaP7yM/'}],
#   'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/EfPiWqaP7yM/',
#   'comments': 'https://www.oreilly.com/radar/four-short-links-12-november-2019/#respond',
#   'published': 'Tue, 12 Nov 2019 05:01:10 +0000',
#   'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=12, tm_hour=5, tm_min=1, tm_sec=10, tm_wday=1, tm_yday=316, tm_isdst=0),
#   'authors': [{'name': 'Nat Torkington'}],
#   'author': 'Nat Torkington',
#   'author_detail': {'name': 'Nat Torkington'},
#   'tags': [{'term': 'Four Short Links', 'scheme': None, 'label': None},
#    {'term': 'Signals', 'scheme': None, 'label': None}],
#   'id': 'https://www.oreilly.com/radar/?p=10835',
#   'guidislink': False,
#   'summary': 'Uyghur Detecting &#8220;Smart&#8221; Camera &#8212; this should start hard conversations in your workplace about what you build. (via BoingBoing) Deep Tech Trends 2019 &#8212; a lot of companies doing a lot of things. So many utility Daleks that will&#8230;clean your floors, clean your toilet, run your landfill, hold your drill&#8230; SandDance &#8212; By using easy-to-understand [&#8230;]',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'Uyghur Detecting &#8220;Smart&#8221; Camera &#8212; this should start hard conversations in your workplace about what you build. (via BoingBoing) Deep Tech Trends 2019 &#8212; a lot of companies doing a lot of things. So many utility Daleks that will&#8230;clean your floors, clean your toilet, run your landfill, hold your drill&#8230; SandDance &#8212; By using easy-to-understand [&#8230;]'},
#   'content': [{'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': '<ol><li><a href="https://ipvm.com/reports/hikvision-uyghur">Uyghur Detecting &#8220;Smart&#8221; Camera</a> &#8212; this should start hard conversations in your workplace about what you build. (via <a href="https://boingboing.net/2019/11/11/ethnicity-detection-camera.html">BoingBoing</a>)</li><li><a href="https://www.slideshare.net/SOSv/deep-tech-trends-2019">Deep Tech Trends 2019</a> &#8212; a lot of companies doing a lot of things. So many utility Daleks that will&#8230;clean your floors, clean your toilet, run your landfill, hold your drill&#8230;</li><li><a href="https://sanddance.js.org/">SandDance</a> &#8212; <em>By using easy-to-understand views, SandDance helps you find insights about your data, which in turn help you tell stories supported by data, build cases based on evidence, test hypotheses, dig deeper into surface explanations, support decisions for purchases, or relate data into a wider, real-world context. SandDance uses unit visualizations, which apply a one-to-one mapping between rows in your database and marks on the screen. Smooth animated transitions between views help you to maintain context as you interact with your data.</em></li><li><a href="https://developers.google.com/machine-learning/guides/rules-of-ml/">Rules of Machine Learning</a> (Google) &#8212; <em>A simple heuristic can get your product out the door. A complex heuristic is unmaintainable. Once you have data and a basic idea of what you are trying to accomplish, move on to machine learning. As in most software engineering tasks, you will want to be constantly updating your approach, whether it is a heuristic or a machine\xad-learned model, and you will find that the machine\xad-learned model is easier to update and maintain.</em></li></ol>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/EfPiWqaP7yM" height="1" width="1" alt=""/>'}],
#   'wfw_commentrss': 'https://www.oreilly.com/radar/four-short-links-12-november-2019/feed/',
#   'slash_comments': '0',
#   'feedburner_origlink': 'https://www.oreilly.com/radar/four-short-links-12-november-2019/'},
#  {'title': 'Four short links: 11 November 2019',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'Four short links: 11 November 2019'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/njtsEULYt_g/'}],
#   'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/njtsEULYt_g/',
#   'comments': 'https://www.oreilly.com/radar/four-short-links-11-november-2019/#respond',
#   'published': 'Mon, 11 Nov 2019 05:01:56 +0000',
#   'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=11, tm_hour=5, tm_min=1, tm_sec=56, tm_wday=0, tm_yday=315, tm_isdst=0),
#   'authors': [{'name': 'Nat Torkington'}],
#   'author': 'Nat Torkington',
#   'author_detail': {'name': 'Nat Torkington'},
#   'tags': [{'term': 'Four Short Links', 'scheme': None, 'label': None},
#    {'term': 'Signals', 'scheme': None, 'label': None}],
#   'id': 'https://www.oreilly.com/radar/?p=10811',
#   'guidislink': False,
#   'summary': 'WebAssembly.sh an open source terminal that uses the WebAssembly Package Manager (WAPM) and local files to run server-side Wasm / WASI modules in a shell-like interface. (via Mikeal Rogers) Russia’s Suspected Internet Cable Spy Ship Appears Off Americas (Forbes) &#8212; assume your network is compromised, as you should always have done. Before enlightenment: encryption. After [&#8230;]',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'WebAssembly.sh an open source terminal that uses the WebAssembly Package Manager (WAPM) and local files to run server-side Wasm / WASI modules in a shell-like interface. (via Mikeal Rogers) Russia’s Suspected Internet Cable Spy Ship Appears Off Americas (Forbes) &#8212; assume your network is compromised, as you should always have done. Before enlightenment: encryption. After [&#8230;]'},
#   'content': [{'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': '<ol><li><a href="https://webassembly.sh/">WebAssembly.sh</a>   <em>an open source terminal that uses the WebAssembly Package Manager (WAPM) and local files to run server-side Wasm / WASI modules in a shell-like interface.</em> (via <a href="https://twitter.com/mikeal/status/1192520347440099335">Mikeal Rogers</a>)</li><li><a href="https://www.forbes.com/sites/hisutton/2019/11/10/russias-suspected-internet-cable-spy-ship-appears-off-americas/#60ae8c6b42d5">Russia’s Suspected Internet Cable Spy Ship Appears Off Americas</a> (Forbes) &#8212; assume your network is compromised, as you should always have done. Before enlightenment: encryption. After enlightenment: encryption.</li><li><a href="https://yannherklotz.com/docs/verismith/verismith_paper.pdf">Finding and Understanding Bugs in FPGA Synthesis Tools</a> &#8212; <em>Every synthesis tool was found to introduce discrepancies between the netlist and the design, and all tools except XST crashed when given valid input. Vivado was found to missynthesise 4% of random testcases that it was given.</em></li><li><a href="https://www.nature.com/articles/s41599-019-0279-9">Fake News Game Confers Psychological Resistance Against Online Misinformation</a> (Nature) &#8212; <em>In the game, players take on the role of a fake news producer and learn to master six documented techniques commonly used in the production of misinformation: polarization, invoking emotions, spreading conspiracy theories, trolling people online, deflecting blame, and impersonating fake accounts. The game draws on an inoculation metaphor, where preemptively exposing, warning, and familiarizing people with the strategies used in the production of fake news helps confer cognitive immunity when exposed to real misinformation. We conducted a large-scale evaluation of the game with N = 15,000 participants in a pre-post gameplay design. We provide initial evidence that people’s ability to spot and resist misinformation improves after gameplay, irrespective of education, age, political ideology, and cognitive style.</em></li></ol>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/njtsEULYt_g" height="1" width="1" alt=""/>'}],
#   'wfw_commentrss': 'https://www.oreilly.com/radar/four-short-links-11-november-2019/feed/',
#   'slash_comments': '0',
#   'feedburner_origlink': 'https://www.oreilly.com/radar/four-short-links-11-november-2019/'},
#  {'title': 'Bitcoin and the disruption of monetary oppression',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'Bitcoin and the disruption of monetary oppression'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/ENi7moVeFTY/'}],
#   'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/ENi7moVeFTY/',
#   'comments': 'https://www.oreilly.com/radar/bitcoin-and-the-disruption-of-monetary-oppression/#respond',
#   'published': 'Fri, 08 Nov 2019 05:10:27 +0000',
#   'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=8, tm_hour=5, tm_min=10, tm_sec=27, tm_wday=4, tm_yday=312, tm_isdst=0),
#   'authors': [{'name': 'Jenn Webb'}],
#   'author': 'Jenn Webb',
#   'author_detail': {'name': 'Jenn Webb'},
#   'tags': [{'term': 'Innovation & Disruption', 'scheme': None, 'label': None},
#    {'term': 'Deep Dive', 'scheme': None, 'label': None},
#    {'term': "Foo Camp '19", 'scheme': None, 'label': None}],
#   'id': 'https://www.oreilly.com/radar/?p=9571',
#   'guidislink': False,
#   'summary': 'In this interview from O&#8217;Reilly Foo Camp 2019, Programming Bitcoin author Jimmy Song talks about why Bitcoin is a profound invention, the impact it&#8217;s already having on society, and its path to monetary relevance. Highlights from the interview include: In the physical world, we have centralized and decentralized scarcity—think numbered prints from artists (centralized) versus [&#8230;]',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'In this interview from O&#8217;Reilly Foo Camp 2019, Programming Bitcoin author Jimmy Song talks about why Bitcoin is a profound invention, the impact it&#8217;s already having on society, and its path to monetary relevance. Highlights from the interview include: In the physical world, we have centralized and decentralized scarcity—think numbered prints from artists (centralized) versus [&#8230;]'},
#   'content': [{'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': '<p>In this interview from O&#8217;Reilly Foo Camp 2019, <a href="https://learning.oreilly.com/library/view/programming-bitcoin/9781492031482/"><em>Programming Bitcoin</em></a> author Jimmy Song talks about why Bitcoin is a profound invention, the impact it&#8217;s already having on society, and its path to monetary relevance.</p>\n\n<p>Highlights from the interview include:</p>\n\n<p>In the physical world, we have centralized and decentralized scarcity—think numbered prints from artists (centralized) versus gold or salt or glass beads (decentralized). Until Bitcoin, Song argues, there was no decentralized scarcity in the digital realm. &#8220;Decentralized digital scarcity is a profound invention,&#8221; Song explains &#8220;because it lets you transfer value without an intermediary. There is no permission involved, there&#8217;s no censorability, and that makes it an excellent, excellent [form of] money.&#8221; (<a href="#t=63">1:03</a>)</p>\n\n<p>One of the tangible social impacts of Bitcoin can be witnessed in the human rights arena. As one example, Song offers an overview of the refugee crisis in Venezuela, explaining that Bitcoin is allowing those wishing to flee the country to sell their belongings and retain their money when crossing the border to Columbia. &#8220;There&#8217;s very clear evidence of this,&#8221; Song explains &#8220;because the price of Bitcoin in Columbia is actually lower than everywhere else in the world because there&#8217;s such a big supply. Four million Venezuelans have left. That&#8217;s 10% of their population. That&#8217;s a serious impact. Usually in refugee crises, it has gotten so bad that people were willing to leave everything behind. With this, they get to carry their wealth. It undermines the Maduro government to a large degree.&#8221; (<a href="#t=351">5:51</a>)</p> \n\n<p>The US&#8217;s market-driven monetary imperialism has led, Song argues, to a sort of global US dollar hegemony—the impact of which is that all global trade is settled in US dollars; if you&#8217;re in Kenya and want to trade with someone in neighboring Nigeria, you have to trade for the US dollar and then back to the Kenyan shilling. Song notes this basically gives the US dominance over everything and allows dictators, who control their economies through their central banks, to use money as a tool of oppression. &#8220;Bitcoin gives you a politically neutral money, one that&#8217;s not dominated by a single country. I say all this about the US dollar, but imagine a world where the Chinese yuan is the dominant currency.&#8221; (<a href="#t=642">10:42</a>)</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/ENi7moVeFTY" height="1" width="1" alt=""/>'}],
#   'wfw_commentrss': 'https://www.oreilly.com/radar/bitcoin-and-the-disruption-of-monetary-oppression/feed/',
#   'slash_comments': '0',
#   'feedburner_origlink': 'https://www.oreilly.com/radar/bitcoin-and-the-disruption-of-monetary-oppression/'},
#  {'title': 'Four short links: 8 November 2019',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'Four short links: 8 November 2019'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/VnkRZWuKkD0/'}],
#   'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/VnkRZWuKkD0/',
#   'comments': 'https://www.oreilly.com/radar/four-short-links-8-november-2019/#respond',
#   'published': 'Fri, 08 Nov 2019 05:01:04 +0000',
#   'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=8, tm_hour=5, tm_min=1, tm_sec=4, tm_wday=4, tm_yday=312, tm_isdst=0),
#   'authors': [{'name': 'Nat Torkington'}],
#   'author': 'Nat Torkington',
#   'author_detail': {'name': 'Nat Torkington'},
#   'tags': [{'term': 'Four Short Links', 'scheme': None, 'label': None},
#    {'term': 'Signals', 'scheme': None, 'label': None}],
#   'id': 'https://www.oreilly.com/radar/?p=10775',
#   'guidislink': False,
#   'summary': 'Probabilistic Scripts for Automating Common-Sense Tasks &#8212; In this talk, I&#8217;ll introduce a new declarative-programming approach for automating common-sense reasoning tasks: probabilistic scripting. A talk from Strange Loop. Infer &#8212; Facebook&#8217;s open source static analysis tool &#8212; if you give Infer some Java or C/C++/Objective-C code, it produces a list of potential bugs. VFRAME &#8212; [&#8230;]',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'Probabilistic Scripts for Automating Common-Sense Tasks &#8212; In this talk, I&#8217;ll introduce a new declarative-programming approach for automating common-sense reasoning tasks: probabilistic scripting. A talk from Strange Loop. Infer &#8212; Facebook&#8217;s open source static analysis tool &#8212; if you give Infer some Java or C/C++/Objective-C code, it produces a list of potential bugs. VFRAME &#8212; [&#8230;]'},
#   'content': [{'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': '<ol><li><a href="https://www.youtube.com/watch?v=MiiWzJE0fEA">Probabilistic Scripts for Automating Common-Sense Tasks</a> &#8212; <em>In this talk, I&#8217;ll introduce a new declarative-programming approach for automating common-sense reasoning tasks: probabilistic scripting.</em> A <a href="https://thestrangeloop.com/2019/probabilistic-scripts-for-automating-common-sense-tasks.html">talk</a> from Strange Loop.</li><li><a href="https://fbinfer.com/">Infer</a> &#8212; Facebook&#8217;s <a href="http://github.com/facebook/infer">open source</a> <em>static analysis tool &#8212; if you give Infer some Java or C/C++/Objective-C code, it produces a list of potential bugs</em>.</li><li><a href="https://ahprojects.com/vframe/">VFRAME</a> &#8212; <em>Visual Forensics and Metadata Extraction is a computer vision toolkit designed for human rights researchers. It aims to bridge the gap between state-of-the-art artificial intelligence used in the commercial sector and make it accessible and tailored to the needs of human rights researchers and investigative journalists working with large video or image datasets.</em></li><li><a href="https://arxiv.org/pdf/1909.02638.pdf">(Un)informed Consent: Studying GDPR Consent Notices in the Field</a> &#8212; Most GDPR consent forms come with pre-checked boxes. Cut to section 4.5, &#8220;Survey Results,&#8221; of this paper for the (not at all) astonishingly low number of people who will click a checkbox to get personalization: 0.4%. (via <a href="https://twitter.com/random_walker/status/1187391482401038336">Arvind Narayanan</a>)</li></ol>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/VnkRZWuKkD0" height="1" width="1" alt=""/>'}],
#   'wfw_commentrss': 'https://www.oreilly.com/radar/four-short-links-8-november-2019/feed/',
#   'slash_comments': '0',
#   'feedburner_origlink': 'https://www.oreilly.com/radar/four-short-links-8-november-2019/'},
#  {'title': 'Highlights from the O’Reilly Software Architecture Conference in Berlin 2019',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'Highlights from the O’Reilly Software Architecture Conference in Berlin 2019'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/XFnuaWaXgQI/'}],
#   'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/XFnuaWaXgQI/',
#   'comments': 'https://www.oreilly.com/radar/highlights-from-software-architecture-berlin-2019/#respond',
#   'published': 'Thu, 07 Nov 2019 20:10:44 +0000',
#   'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=7, tm_hour=20, tm_min=10, tm_sec=44, tm_wday=3, tm_yday=311, tm_isdst=0),
#   'authors': [{'name': 'Mac Slocum'}],
#   'author': 'Mac Slocum',
#   'author_detail': {'name': 'Mac Slocum'},
#   'tags': [{'term': 'Next Architecture', 'scheme': None, 'label': None},
#    {'term': 'Signals', 'scheme': None, 'label': None},
#    {'term': 'Software Architecture Berlin 2019',
#     'scheme': None,
#     'label': None}],
#   'id': 'https://www.oreilly.com/radar/?p=10569',
#   'guidislink': False,
#   'summary': 'Experts from across the software architecture world came together in Berlin for the O&#8217;Reilly Software Architecture Conference. Below you&#8217;ll find links to highlights from the event. Cognitive biases in the architect&#8217;s life Birgitta Boeckeler covers some of the cognitive biases that can trip up architects. Watch &#8220;Cognitive biases in the architect&#8217;s life&#8220; The three-headed dog: [&#8230;]',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'Experts from across the software architecture world came together in Berlin for the O&#8217;Reilly Software Architecture Conference. Below you&#8217;ll find links to highlights from the event. Cognitive biases in the architect&#8217;s life Birgitta Boeckeler covers some of the cognitive biases that can trip up architects. Watch &#8220;Cognitive biases in the architect&#8217;s life&#8220; The three-headed dog: [&#8230;]'},
#   'content': [{'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': '<p>Experts from across the software architecture world came together in Berlin for the <a href="https://conferences.oreilly.com/software-architecture/sa-eu">O&#8217;Reilly Software Architecture Conference</a>. Below you&#8217;ll find links to highlights from the event.</p>\n<h2>Cognitive biases in the architect&#8217;s life</h2>\n<p>Birgitta Boeckeler covers some of the cognitive biases that can trip up architects.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/cognitive-biases-in-the-architects-life">Cognitive biases in the architect&#8217;s life</a>&#8220;</li>\n</ul>\n<h2>The three-headed dog: Architecture, process, structure</h2>\n<p>Allen Holub shows you how architecture, process, and structure interact, and how to fix misalignment that’s sucking the life out of your productivity.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/the-three-headed-dog-architecture-process-structure">The three-headed dog: Architecture, process, structure</a>&#8220;</li>\n</ul>\n<h2>Modern machine learning architectures: Data and hardware and platform, oh my</h2>\n<p>Brian Sletten takes a deep dive into the intersection of data, models, hardware, language, architecture, and machine learning systems.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/modern-machine-learning-architectures">Modern machine learning architectures: Data and hardware and platform, oh my</a>&#8220;</li>\n</ul>\n<h2>From the trenches: Patrick Kua</h2>\n<p>Neal Ford interviews Patrick Kua about his career path and his work as an architect.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/from-the-trenches-patrick-kua">From the trenches: Patrick Kua</a>&#8220;</li>\n</ul>\n<h2>The new norms of cloud native</h2>\n<p>Cheryl Hung discusses the state of cloud native tools and communities.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/the-new-norms-of-cloud-native">The new norms of cloud native</a>&#8220;</li>\n</ul>\n<div class="hidden">\n<!--unsigned--></p>\n<h2>Next data platform architecture: Distributed Data Mesh</h2>\n<p>Zhamak Dehghani introduces data mesh, the next-generation data platform that draws from modern distributed architecture.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/next-data-platform-architecture-distributed-data-mesh">Next data platform architecture: Distributed Data Mesh</a>&#8220;</li>\n</ul>\n</div>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/XFnuaWaXgQI" height="1" width="1" alt=""/>'}],
#   'wfw_commentrss': 'https://www.oreilly.com/radar/highlights-from-software-architecture-berlin-2019/feed/',
#   'slash_comments': '0',
#   'feedburner_origlink': 'https://www.oreilly.com/radar/highlights-from-software-architecture-berlin-2019/'},
#  {'title': 'Highlights from the O’Reilly Velocity Conference in Berlin 2019',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'Highlights from the O’Reilly Velocity Conference in Berlin 2019'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/V2KqZ95Mbgs/'}],
#   'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/V2KqZ95Mbgs/',
#   'comments': 'https://www.oreilly.com/radar/highlights-from-velocity-berlin-2019/#respond',
#   'published': 'Thu, 07 Nov 2019 20:09:07 +0000',
#   'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=7, tm_hour=20, tm_min=9, tm_sec=7, tm_wday=3, tm_yday=311, tm_isdst=0),
#   'authors': [{'name': 'Mac Slocum'}],
#   'author': 'Mac Slocum',
#   'author_detail': {'name': 'Mac Slocum'},
#   'tags': [{'term': 'Next Architecture', 'scheme': None, 'label': None},
#    {'term': 'Signals', 'scheme': None, 'label': None},
#    {'term': 'Velocity Conference Berlin 2019', 'scheme': None, 'label': None}],
#   'id': 'https://www.oreilly.com/radar/?p=10577',
#   'guidislink': False,
#   'summary': 'People from across the cloud native and distributed systems worlds came together in Berlin for the O&#8217;Reilly Velocity Conference. Below you&#8217;ll find links to highlights from the event. My love letter to computer science is very short and I also forgot to mail it James Mickens shares his concerns and frustrations with today&#8217;s technology. Watch [&#8230;]',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'People from across the cloud native and distributed systems worlds came together in Berlin for the O&#8217;Reilly Velocity Conference. Below you&#8217;ll find links to highlights from the event. My love letter to computer science is very short and I also forgot to mail it James Mickens shares his concerns and frustrations with today&#8217;s technology. Watch [&#8230;]'},
#   'content': [{'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': '<p>People from across the cloud native and distributed systems worlds came together in Berlin for the <a href="https://conferences.oreilly.com/velocity/vl-eu">O&#8217;Reilly Velocity Conference</a>. Below you&#8217;ll find links to highlights from the event.</p>\n<h2>My love letter to computer science is very short and I also forgot to mail it</h2>\n<p>James Mickens shares his concerns and frustrations with today&#8217;s technology.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/my-love-letter-to-computer-science-is-very-short">My love letter to computer science is very short and I also forgot to mail ity</a>&#8220;</li>\n</ul>\n<h2>Everything is a little bit broken; or, The illusion of control</h2>\n<p>Heidi Waterhouse outlines ways to handle uncertainty by adding in error budgets, layered access, and other accommodations for failure.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/everything-is-a-little-bit-broken">Everything is a little bit broken; or, The illusion of control</a>&#8220;</li>\n</ul>\n<h2>Observability: Understanding production through your customers&#8217; eyes</h2>\n<p>Christine Yen says observability isn’t just for ops folks, but it’s not only about engineering roles, either.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/observability-understanding-production-through-your-customers-eyes">Observability: Understanding production through your customers&#8217; eyes</a>&#8220;</li>\n</ul>\n<h2>Secure reliable systems</h2>\n<p>Ana Oprea provides insights and strategies for baking security into your systems.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/secure-reliable-systems-velocity-eu-19">Secure reliable systems</a>&#8220;</li>\n</ul>\n<h2>How to deploy infrastructure in just 13.8 billion years</h2>\n<p>Ingrid Burrington looks at how reframing the time scales of computation can change the way your build infrastructure.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/how-to-deploy-infrastructure-in-just-13-point-8-billion-years">How to deploy infrastructure in just 13.8 billion years</a>&#8220;</li>\n</ul>\n<h2>The ultimate guide to complicated systems</h2>\n<p>Jennifer Davis explores how sustainable engineering practices can enable technical and strategic direction.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/the-ultimate-guide-to-complicated-systems">The ultimate guide to complicated systems</a>&#8220;</li>\n</ul>\n<h2>5 things Go taught me about open source?</h2>\n<p>Dave Cheney talks about the unexpected things he learned while trying to convince programmers to try Go.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/5-things-go-taught-me-about-open-source">5 things Go taught me about open source?</a>&#8220;</li>\n</ul>\n<h2>Building high-performing engineering teams, one pixel at a time</h2>\n<p>Lena Reinhard discusses ways you can make distributed teams strong, deliberate, and productive.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/building-high-performing-engineering-teams-one-pixel-at-a-time">Building high-performing engineering teams, one pixel at a time</a>&#8220;</li>\n</ul>\n<h2>Controlled chaos: The inevitable marriage of DevOps and security</h2>\n<p>Kelly Shortridge explains why chaos and resilience engineering represent the future of security programs.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/controlled-chaos-the-inevitable-marriage-of-devops-and-security">Controlled chaos: The inevitable marriage of DevOps and security</a>&#8220;</li>\n</ul>\n<div class="hidden">\n<!--unsigned--></p>\n<h2>The power of good abstractions in systems design</h2>\n<p>Lorenzo Saino looks at how good abstractions make it possible to identify and apply solutions to seemingly unrelated problems.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/the-power-of-good-abstractions-in-systems-design">The power ...
#   'wfw_commentrss': 'https://www.oreilly.com/radar/highlights-from-velocity-berlin-2019/feed/',
#   'slash_comments': '0',
#   'feedburner_origlink': 'https://www.oreilly.com/radar/highlights-from-velocity-berlin-2019/'},
#  {'title': 'From the trenches: Patrick Kua',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'From the trenches: Patrick Kua'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/0JSKwm4FfEE/'}],
#   'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/0JSKwm4FfEE/',
#   'comments': 'https://www.oreilly.com/radar/from-the-trenches-patrick-kua/#respond',
#   'published': 'Thu, 07 Nov 2019 20:00:48 +0000',
#   'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=7, tm_hour=20, tm_min=0, tm_sec=48, tm_wday=3, tm_yday=311, tm_isdst=0),
#   'authors': [{'name': 'Patrick Kua and Neal Ford'}],
#   'author': 'Patrick Kua and Neal Ford',
#   'author_detail': {'name': 'Patrick Kua and Neal Ford'},
#   'tags': [{'term': 'Next Architecture', 'scheme': None, 'label': None},
#    {'term': 'Software Architecture Berlin 2019',
#     'scheme': None,
#     'label': None}],
#   'id': 'https://www.oreilly.com/radar/?p=10503',
#   'guidislink': False,
#   'summary': 'This is a keynote highlight from the O&#8217;Reilly Software Architecture Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'This is a keynote highlight from the O&#8217;Reilly Software Architecture Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.'},
#   'content': [{'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': '<p>This is a keynote highlight from the O&#8217;Reilly Software Architecture Conference in Berlin 2019. <a href="https://learning.oreilly.com/videos/oreilly-software-architecture/9781492050728/9781492050728-video328593">Watch the full version of this keynote on the O&#8217;Reilly online learning platform</a>.</p>\n<p>You can also <a href="https://www.oreilly.com/radar/highlights-from-software-architecture-berlin-2019">see other highlights from the event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/0JSKwm4FfEE" height="1" width="1" alt=""/>'}],
#   'wfw_commentrss': 'https://www.oreilly.com/radar/from-the-trenches-patrick-kua/feed/',
#   'slash_comments': '0',
#   'feedburner_origlink': 'https://www.oreilly.com/radar/from-the-trenches-patrick-kua/'},
#  {'title': '5 things Go taught me about open source?',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
# ...
#   'author': 'Kelly Shortridge',
#   'author_detail': {'name': 'Kelly Shortridge'},
#   'tags': [{'term': 'Next Architecture', 'scheme': None, 'label': None},
#    {'term': 'Velocity Conference Berlin 2019', 'scheme': None, 'label': None}],
#   'id': 'https://www.oreilly.com/radar/?p=10561',
#   'guidislink': False,
#   'summary': 'This is a keynote highlight from the O&#8217;Reilly Velocity Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'This is a keynote highlight from the O&#8217;Reilly Velocity Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.'},
#   'content': [{'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': '<p>This is a keynote highlight from the O&#8217;Reilly Velocity Conference in Berlin 2019. <a href="https://learning.oreilly.com/videos/oreilly-velocity-conference/9781492050742/9781492050742-video328467">Watch the full version of this keynote on the O&#8217;Reilly online learning platform</a>.</p>\n<p>You can also <a href="https://www.oreilly.com/radar/highlights-from-velocity-berlin-2019">see other highlights from the event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/QnGi3gdzKj0" height="1" width="1" alt=""/>'}],
#   'wfw_commentrss': 'https://www.oreilly.com/radar/controlled-chaos-the-inevitable-marriage-of-devops-and-security/feed/',
#   'slash_comments': '0',
#   'feedburner_origlink': 'https://www.oreilly.com/radar/controlled-chaos-the-inevitable-marriage-of-devops-and-security/'},
#  {'title': 'The ultimate guide to complicated systems',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'The ultimate guide to complicated systems'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/AlXZ2UUW79M/'}],
#   'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/AlXZ2UUW79M/',
#   'comments': 'https://www.oreilly.com/radar/the-ultimate-guide-to-complicated-systems/#respond',
#   'published': 'Thu, 07 Nov 2019 20:00:17 +0000',
#   'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=7, tm_hour=20, tm_min=0, tm_sec=17, tm_wday=3, tm_yday=311, tm_isdst=0),
#   'authors': [{'name': 'Jennifer Davis'}],
#   'author': 'Jennifer Davis',
#   'author_detail': {'name': 'Jennifer Davis'},
#   'tags': [{'term': 'Next Architecture', 'scheme': None, 'label': None},
#    {'term': 'Velocity Conference Berlin 2019', 'scheme': None, 'label': None}],
#   'id': 'https://www.oreilly.com/radar/?p=10540',
#   'guidislink': False,
#   'summary': 'This is a keynote highlight from the O&#8217;Reilly Velocity Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'This is a keynote highlight from the O&#8217;Reilly Velocity Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.'},
#   'content': [{'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': '<p>This is a keynote highlight from the O&#8217;Reilly Velocity Conference in Berlin 2019. <a href="https://learning.oreilly.com/videos/oreilly-velocity-conference/9781492050742/9781492050742-video328466">Watch the full version of this keynote on the O&#8217;Reilly online learning platform</a>.</p>\n<p>You can also <a href="https://www.oreilly.com/radar/highlights-from-velocity-berlin-2019">see other highlights from the event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/AlXZ2UUW79M" height="1" width="1" alt=""/>'}],
#   'wfw_commentrss': 'https://www.oreilly.com/radar/the-ultimate-guide-to-complicated-systems/feed/',
#   'slash_comments': '0',
#   'feedburner_origlink': 'https://www.oreilly.com/radar/the-ultimate-guide-to-complicated-systems/'},
#  {'title': 'Cognitive biases in the architect’s life',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'Cognitive biases in the architect’s life'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/MCKQixUPlMQ/'}],
#   'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/MCKQixUPlMQ/',
#   'comments': 'https://www.oreilly.com/radar/cognitive-biases-in-the-architects-life/#respond',
#   'published': 'Thu, 07 Nov 2019 20:00:07 +0000',
#   'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=7, tm_hour=20, tm_min=0, tm_sec=7, tm_wday=3, tm_yday=311, tm_isdst=0),
#   'authors': [{'name': 'Birgitta Boeckeler'}],
#   'author': 'Birgitta Boeckeler',
#   'author_detail': {'name': 'Birgitta Boeckeler'},
#   'tags': [{'term': 'Next Architecture', 'scheme': None, 'label': None},
#    {'term': 'Software Architecture Berlin 2019',
#     'scheme': None,
#     'label': None}],
#   'id': 'https://www.oreilly.com/radar/?p=10497',
#   'guidislink': False,
#   'summary': 'This is a keynote highlight from the O&#8217;Reilly Software Architecture Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'This is a keynote highlight from the O&#8217;Reilly Software Architecture Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.'},
#   'content': [{'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': '<p>This is a keynote highlight from the O&#8217;Reilly Software Architecture Conference in Berlin 2019. <a href="https://learning.oreilly.com/videos/oreilly-software-architecture/9781492050728/9781492050728-video328591">Watch the full version of this keynote on the O&#8217;Reilly online learning platform</a>.</p>\n<p>You can also <a href="https://www.oreilly.com/radar/highlights-from-software-architecture-berlin-2019">see other highlights from the event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/MCKQixUPlMQ" height="1" width="1" alt=""/>'}],
#   'wfw_commentrss': 'https://www.oreilly.com/radar/cognitive-biases-in-the-architects-life/feed/',
#   'slash_comments': '0',
#   'feedburner_origlink': 'https://www.oreilly.com/radar/cognitive-biases-in-the-architects-life/'},
#  {'title': 'The three-headed dog: Architecture, process, structure',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'The three-headed dog: Architecture, process, structure'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/tUBOtwDRLBU/'}],
#   'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/tUBOtwDRLBU/',
#   'comments': 'https://www.oreilly.com/radar/the-three-headed-dog-architecture-process-structure/#respond',
#   'published': 'Thu, 07 Nov 2019 20:00:06 +0000',
#   'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=7, tm_hour=20, tm_min=0, tm_sec=6, tm_wday=3, tm_yday=311, tm_isdst=0),
#   'authors': [{'name': 'Allen Holub'}],
#   'author': 'Allen Holub',
#   'author_detail': {'name': 'Allen Holub'},
#   'tags': [{'term': 'Next Architecture', 'scheme': None, 'label': None},
#    {'term': 'Software Architecture Berlin 2019',
#     'scheme': None,
#     'label': None}],
#   'id': 'https://www.oreilly.com/radar/?p=10490',
#   'guidislink': False,
#   'summary': 'This is a keynote highlight from the O&#8217;Reilly Software Architecture Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'This is a keynote highlight from the O&#8217;Reilly Software Architecture Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.'},
#   'content': [{'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': '<p>This is a keynote highlight from the O&#8217;Reilly Software Architecture Conference in Berlin 2019. <a href="https://learning.oreilly.com/videos/oreilly-software-architecture/9781492050728/9781492050728-video328592">Watch the full version of this keynote on the O&#8217;Reilly online learning platform</a>.</p>\n<p>You can also <a href="https://www.oreilly.com/radar/highlights-from-software-architecture-berlin-2019">see other highlights from the event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/tUBOtwDRLBU" height="1" width="1" alt=""/>'}],
#   'wfw_commentrss': 'https://www.oreilly.com/radar/the-three-headed-dog-architecture-process-structure/feed/',
#   'slash_comments': '0',
#   'feedburner_origlink': 'https://www.oreilly.com/radar/the-three-headed-dog-architecture-process-structure/'},
#  {'title': 'A world of deepfakes',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'A world of deepfakes'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9PQAmHRa6oA/'}],
#   'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9PQAmHRa6oA/',
#   'comments': 'https://www.oreilly.com/radar/a-world-of-deepfakes/#respond',
#   'published': 'Thu, 07 Nov 2019 14:00:50 +0000',
#   'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=7, tm_hour=14, tm_min=0, tm_sec=50, tm_wday=3, tm_yday=311, tm_isdst=0),
#   'authors': [{'name': 'Ben Lorica and Mike Loukides'}],
#   'author': 'Ben Lorica and Mike Loukides',
#   'author_detail': {'name': 'Ben Lorica and Mike Loukides'},
#   'tags': [{'term': 'AI & ML', 'scheme': None, 'label': None},
#    {'term': 'Deep Dive', 'scheme': None, 'label': None}],
#   'id': 'https://www.oreilly.com/radar/?p=10617',
#   'guidislink': False,
#   'summary': 'Deepfakes have been very much in the news for the past two years. It’s time to think about what deepfakes are and what they mean. Where do they come from? Why now? Is this just a natural evolution in the history of technology? Deepfakes are media that are created by AI. They appear to be [&#8230;]',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'Deepfakes have been very much in the news for the past two years. It’s time to think about what deepfakes are and what they mean. Where do they come from? Why now? Is this just a natural evolution in the history of technology? Deepfakes are media that are created by AI. They appear to be [&#8230;]'},
#   'content': [{'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': '<p>Deepfakes have been very much in the news for the past two years. It’s time to think about what deepfakes are and what they mean. Where do they come from? Why now? Is this just a natural evolution in the history of technology?</p>\n\n\n\n<p>Deepfakes are media that are created by AI. They appear to be genuine (e.g., a <a href="https://www.theverge.com/tldr/2018/4/17/17247334/ai-fake-news-video-barack-obama-jordan-peele-buzzfeed">video of President Obama</a>) but have limited connection to reality. An audio track can be created that sounds indistinguishable from the victim, saying something the victim would never have said. Video can be generated from existing videos or photos that match the soundtrack, so that the mouth moves correctly and the facial expressions look natural. It’s not surprising that humans have trouble detecting fakes; with the current technology, even shallow fakes are too good.</p>\n\n\n\n<p>Deepfakes are the logical extension of older AI research. It wasn’t long ago that we read about AI generating new paintings in the style of <a href="https://www.pcworld.com/article/3053520/ai-just-3d-printed-a-brand-new-rembrandt-and-its-shockingly-good.html">Rembrandt</a> and other Dutch Masters, stylizing pictures in the style of <a href="https://qz.com/495614/computers-can-now-paint-like-van-gogh-and-picasso/">Van Gogh and Picasso</a>, and so on. At the time, there was more concern about the future of human creativity: would we still need artists? Would we live in a world full of fake Van Goghs? We shrugged those “fakes” off because we were asking the wrong questions. We don’t need more Van Goghs any more than we need more <a href="https://en.wikipedia.org/wiki/Velvet_Elvis">Elvises on velvet</a>. We may end up with a few fake Rembrandts where they shouldn’t be, but the art world will survive.</p>\n\n\n\n<p>If that’s the wrong question, what’s the right one? The problem with deepfakes is that simulating an artist’s style collided with the rise of fake news. Fake news isn’t new by any means; there have always been conspiracy theorists who are marvelously skeptical of “traditional” media, but are completely unskeptical of their own sources, whether they claim that Tibetans are spying on us through a system of underground tunnels or that vaccinations cause autism.</p>\n\n\n\n<p>To this collision, add three more factors: the democratization of AI, the decrease in the cost of computing power, and the phenomenon of virality. Deepfakes jumped out of the lab and into the streets. You don’t need a Ph.D. to generate fake media, nor do you need the resources of a nation state to acquire enough computing power. Some easily available tools and a credit card to buy time on AWS are all you need. In some cases, it only takes an app: in China, a popular iPhone app <a href="https://www.theverge.com/2019/9/2/20844338/zao-deepfake-app-movie-tv-show-face-replace-privacy-policy-concerns">lets you put your face into movie clips</a>. (Ironically, backlash against this app didn’t take place because of the fakes but because of the app’s privacy policy.) Once you’ve created a fake, you can use social media to propagate it. YouTube’s and Facebook’s algorithms for optimizing “engagement” can make any content viral in seconds.</p>\n\n\n\n<p>That all adds up to a scary picture. We will certainly see deepfakes in politics, though as security expert @thegrugq <a href="https://medium.com/@thegrugq/cheap-fakes-beat-deep-fakes-b1ac91e44837">points out</a>, cheap fakes are better than deepfakes for shaping public opinion. Deepfakes might be more dangerous in computer security, where they can be used to circumvent authentication or perform high-quality phishing attacks. Symantec <a href="https://www.ft.com/content/63cd4010-bfce-11e9-b350-db00d509634e">has reported</a> that it has seen such attacks in the field, and recently an <a href="https://beta.washingtonpost.com/technology/2019/09/04/an-artificial-intelligence-first-voice-mimicking- ...
#   'wfw_commentrss': 'https://www.oreilly.com/radar/a-world-of-deepfakes/feed/',
#   'slash_comments': '0',
#   'feedburner_origlink': 'https://www.oreilly.com/radar/a-world-of-deepfakes/'}]

# %% [markdown]
# ### 6. Obtain a list of components (keys) available for an entry.
#
# *Hint: Remember to index first before requesting the keys*

# %%
list(rss.entries[0].keys())
# Out:
# ['title',
#  'title_detail',
#  'links',
#  'link',
#  'comments',
#  'published',
#  'published_parsed',
#  'authors',
#  'author',
#  'author_detail',
#  'tags',
#  'id',
#  'guidislink',
#  'summary',
#  'summary_detail',
#  'content',
#  'wfw_commentrss',
#  'slash_comments',
#  'feedburner_origlink']

# %% [markdown]
# ### 7. Extract a list of entry titles.

# %%
titles = [rss.entries[i].title for i in range(len(rss.entries))]
titles
# Out:
# ['Four short links: 13 November 2019',
#  'O’Reilly serverless survey 2019: Concerns, what works, and what to expect',
#  'Improving the military UX',
#  'Four short links: 12 November 2019',
#  'Four short links: 11 November 2019',
#  'Bitcoin and the disruption of monetary oppression',
#  'Four short links: 8 November 2019',
#  'Highlights from the O’Reilly Software Architecture Conference in Berlin 2019',
#  'Highlights from the O’Reilly Velocity Conference in Berlin 2019',
#  'From the trenches: Patrick Kua',
#  '5 things Go taught me about open source?',
#  'Building high-performing engineering teams, one pixel at a time',
#  'How to deploy infrastructure in just 13.8 billion years',
#  'Controlled chaos: The inevitable marriage of DevOps and security',
#  'The ultimate guide to complicated systems',
#  'Cognitive biases in the architect’s life',
#  'The three-headed dog: Architecture, process, structure',
#  'A world of deepfakes']

# %% [markdown]
# ### 8. Calculate the percentage of "Four short links" entry titles.

# %%
count=0
for u in titles:
    if "Four short links" in u:
        count+=1
    else:
        pass
len(titles)/count
# Out:
# 4.5

# %% [markdown]
# ### 9. Create a Pandas data frame from the feed's entries.

# %%
import pandas as pd

# %%
df=pd.DataFrame(rss.entries)

# %% [markdown]
# ### 10. Count the number of entries per author and sort them in descending order.

# %%
df.groupby('author', as_index=False).agg({'title':'count'})
df.sort_values('entries', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-788c13adad23> in <module>
#       1 df.groupby('author', as_index=False).agg({'title':'count'})
# ----> 2 df.sort_values('entries', ascending=False)
#
# /home/ivan/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    5006
#    5007             by = by[0]
# -> 5008             k = self._get_label_or_level_values(by, axis=axis)
#    5009
#    5010             if isinstance(ascending, (tuple, list)):
#
# /home/ivan/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1772             values = self.axes[axis].get_level_values(key)._values
#    1773         else:
# -> 1774             raise KeyError(key)
#    1775
#    1776         # Check for duplicates
#
# KeyError: 'entries'

# %% [markdown]
# ### 11. Add a new column to the data frame that contains the length (number of characters) of each entry title. Return a data frame that contains the title, author, and title length of each entry in descending order (longest title length at the top).

# %%
df['title_length'] = df['title'].apply(len)
df[['title', 'author', 'title_length']].sort_values('title_length', ascending=False).head()
# Out:
#                                                 title  \
# 7   Highlights from the O’Reilly Software Architec...
# 1   O’Reilly serverless survey 2019: Concerns, wha...
# 13  Controlled chaos: The inevitable marriage of D...
# 8   Highlights from the O’Reilly Velocity Conferen...
# 11  Building high-performing engineering teams, on...
#
#                                  author  title_length
# 7                            Mac Slocum            76
# 1   Roger Magoulas and Chris Guzikowski            73
# 13                     Kelly Shortridge            64
# 8                            Mac Slocum            63
# 11                        Lena Reinhard            63

# %% [markdown]
# ### 12. Create a list of entry titles whose summary includes the phrase "machine learning."

# %%
print(list(df.loc["machine learning" in df.title]))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/ivan/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-246709fd6774> in <module>
# ----> 1 print(list(df.loc["machine learning" in df.title]))
#
# /home/ivan/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1422
#    1423             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1424             return self._getitem_axis(maybe_callable, axis=axis)
#    1425
#    1426     def _is_scalar_access(self, key: Tuple):
#
# /home/ivan/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1848         # fall thru to straight lookup
#    1849         self._validate_key(key, axis)
# -> 1850         return self._get_label(key, axis=axis)
#    1851
#    1852
#
# /home/ivan/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#     158             raise IndexingError("no slices here, handle elsewhere")
#     159
# --> 160         return self.obj._xs(label, axis=axis)
#     161
#     162     def _get_loc(self, key: int, axis: int):
#
# /home/ivan/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3735             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3736         else:
# -> 3737             loc = self.index.get_loc(key)
#    3738
#    3739             if isinstance(loc, np.ndarray):
#
# /home/ivan/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     377             except ValueError:
#     378                 raise KeyError(key)
# --> 379         return super().get_loc(key, method=method, tolerance=tolerance)
#     380
#     381     @Appender(_index_shared_docs["get_indexer"])
#
# /home/ivan/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: False
